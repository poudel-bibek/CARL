# %%
# set parameters here
NUM_ROLLOUTS = 5
LENGTH = 260
NUM_CONTROLLED = 13

# %%
#### Efficiency ####
# Make sure to set the efficiency to true at test time in the controller file and have those files at exp_configs
# Make sure to have the right leader
# !python test_rllib.py ./Ours/Trained_policies/60_percent/PPO_MultiAgentDensityAwareRLEnv-v1_ed546dfe_2024-02-14_17-18-06nijs5agx 200\
--method ours13x --length $LENGTH --num_rollouts 20 --render --gen_emission --shock --num_controlled $NUM_CONTROLLED
# Out:
# 2024-03-28 14:06:52,070	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2024-03-28 14:06:52,071	INFO resource_spec.py:216 -- Starting Ray with 31.74 GiB memory available for workers and up to 15.89 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2024-03-28 14:06:53,696	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2024-03-28 14:06:53,699	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2024-03-28 14:06:56,491	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:06:56,537	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/Trained_policies/60_percent/PPO_MultiAgentDensityAwareRLEnv-v1_ed546dfe_2024-02-14_17-18-06nijs5agx/checkpoint_200/checkpoint-200
# 2024-03-28 14:06:56,537	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 9000000, '_time_total': 30950.06327533722, '_episodes_total': 1998}
#
# -----------------------
# ring length: 260
# v_max: 5.139779427502188
# -----------------------
#
# Directory: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/
#
# 2024-03-28 14:07:00,298	ERROR worker.py:679 -- Calling ray.init() again after it has already been called.
#
# Checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
#
# 2024-03-28 14:07:03,660	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:07:03,739	INFO trainable.py:346 -- Restored from checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
# 2024-03-28 14:07:03,739	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 4520000, '_time_total': 6542.175364017487, '_episodes_total': 998}
#
#
# Leader agent restored
# <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f1627b9a9b0>
# Frequency: 19
# Intensity: -1.6621782786145989
# Duration: 2.1
# Intensity: -1.0634000685908638
# Duration: 0.7
# Intensity: -2.9971262007571715
# Duration: 1.9
# Intensity: -1.0322335482894684
# Duration: 0.2
# Intensity: -2.451719502364697
# Duration: 1.5
# Intensity: -2.506751622784261
# Duration: 1.6
# Intensity: -2.2897048217379856
# Duration: 1.7
# Intensity: -2.1510931386369823
# Duration: 2.4
# Intensity: -1.3816684546446045
# Duration: 0.9
# Intensity: -2.2432416356290634
# Duration: 1.7
# Intensity: -1.506392316266275
# Duration: 2.4
# Intensity: -1.3457255912835953
# Duration: 1.0
# Intensity: -1.0769093322043015
# Duration: 0.5
# Intensity: -1.2550729067106985
# Duration: 0.4
# Intensity: -1.9259338846963125
# Duration: 1.7
# Intensity: -1.7819390689140382
# Duration: 2.4
# Intensity: -1.3618223133360188
# Duration: 0.7
# Intensity: -1.4270455704181555
# Duration: 2.1
# Intensity: -1.3177941639269946
# Duration: 0.5
# Durations:  [21.  7. 19.  2. 15. 16. 17. 24.  9. 17. 24. 10.  5.  4. 17. 24.  7. 21.
#   5.]
# Start times:  [5500 5666 5832 5999 6165 6331 6498 6664 6831 6997 7163 7330 7496 7663
#  7829 7995 8162 8328 8495]
# End times:  [5521.0, 5673.0, 5851.0, 6001.0, 6180.0, 6347.0, 6515.0, 6688.0, 6840.0, 7014.0, 7187.0, 7340.0, 7501.0, 7667.0, 7846.0, 8019.0, 8169.0, 8349.0, 8500.0]
# Shock times:
#  [[5500. 5521.]
#  [5666. 5673.]
#  [5832. 5851.]
#  [5999. 6001.]
#  [6165. 6180.]
#  [6331. 6347.]
#  [6498. 6515.]
#  [6664. 6688.]
#  [6831. 6840.]
#  [6997. 7014.]
#  [7163. 7187.]
#  [7330. 7340.]
#  [7496. 7501.]
#  [7663. 7667.]
#  [7829. 7846.]
#  [7995. 8019.]
#  [8162. 8169.]
#  [8328. 8349.]
#  [8495. 8500.]]
# Step = 5500, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5501, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5502, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5503, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5504, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5505, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5506, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5507, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5508, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5509, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5510, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5511, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5512, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5513, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5514, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5515, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5516, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5517, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5518, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5519, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5520, Shock params: -1.6621782786145989, 2.1, 19 applied to vehicle human_11_6
#
# Step = 5666, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5667, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5668, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5669, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5670, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5671, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5672, Shock params: -1.0634000685908638, 0.7, 19 applied to vehicle human_11_4
#
# Step = 5832, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5833, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5834, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5835, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5836, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5837, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5838, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5839, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5840, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5841, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5842, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5843, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5844, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5845, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5846, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5847, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5848, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5849, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5850, Shock params: -2.9971262007571715, 1.9, 19 applied to vehicle human_11_7
#
# Step = 5999, Shock params: -1.0322335482894684, 0.2, 19 applied to vehicle human_11_5
#
# Step = 6000, Shock params: -1.0322335482894684, 0.2, 19 applied to vehicle human_11_5
#
# Step = 6165, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6166, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
# Step = 6167, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6168, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6169, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6170, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6171, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6172, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6173, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6174, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6175, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6176, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6177, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6178, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6179, Shock params: -2.451719502364697, 1.5, 19 applied to vehicle human_11_6
#
# Step = 6331, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6332, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6333, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6334, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6335, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6336, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6337, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6338, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6339, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6340, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6341, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6342, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6343, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6344, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6345, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6346, Shock params: -2.506751622784261, 1.6, 19 applied to vehicle human_11_4
#
# Step = 6498, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6499, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6500, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6501, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6502, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6503, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6504, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6505, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6506, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6507, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6508, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6509, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6510, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6511, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6512, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6513, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6514, Shock params: -2.2897048217379856, 1.7, 19 applied to vehicle human_11_8
#
# Step = 6664, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6665, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6666, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6667, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6668, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6669, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6670, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6671, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6672, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6673, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6674, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6675, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6676, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6677, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6678, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6679, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6680, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6681, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6682, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6683, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6684, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6685, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6686, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6687, Shock params: -2.1510931386369823, 2.4, 19 applied to vehicle human_11_3
#
# Step = 6831, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6832, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6833, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6834, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6835, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6836, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6837, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6838, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6839, Shock params: -1.3816684546446045, 0.9, 19 applied to vehicle human_11_8
#
# Step = 6997, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 6998, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 6999, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7000, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7001, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7002, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7003, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7004, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7005, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7006, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7007, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7008, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7009, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7010, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7011, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7012, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
# Step = 7013, Shock params: -2.2432416356290634, 1.7, 19 applied to vehicle human_11_1
#
# Step = 7163, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7164, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7165, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7166, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7167, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7168, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7169, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7170, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7171, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7172, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7173, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7174, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7175, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7176, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7177, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7178, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7179, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7180, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7181, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7182, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7183, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7184, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7185, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7186, Shock params: -1.506392316266275, 2.4, 19 applied to vehicle human_11_3
#
# Step = 7330, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7331, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7332, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7333, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7334, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7335, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7336, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7337, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7338, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7339, Shock params: -1.3457255912835953, 1.0, 19 applied to vehicle human_11_7
#
# Step = 7496, Shock params: -1.0769093322043015, 0.5, 19 applied to vehicle human_11_6
#
# Step = 7497, Shock params: -1.0769093322043015, 0.5, 19 applied to vehicle human_11_6
#
# Step = 7498, Shock params: -1.0769093322043015, 0.5, 19 applied to vehicle human_11_6
#
# Step = 7499, Shock params: -1.0769093322043015, 0.5, 19 applied to vehicle human_11_6
#
# Step = 7500, Shock params: -1.0769093322043015, 0.5, 19 applied to vehicle human_11_6
#
# Step = 7663, Shock params: -1.2550729067106985, 0.4, 19 applied to vehicle human_11_2
#
# Step = 7664, Shock params: -1.2550729067106985, 0.4, 19 applied to vehicle human_11_2
#
# Step = 7665, Shock params: -1.2550729067106985, 0.4, 19 applied to vehicle human_11_2
#
# Step = 7666, Shock params: -1.2550729067106985, 0.4, 19 applied to vehicle human_11_2
#
# Step = 7829, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7830, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7831, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7832, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7833, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7834, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7835, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7836, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7837, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7838, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7839, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7840, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7841, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7842, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7843, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7844, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7845, Shock params: -1.9259338846963125, 1.7, 19 applied to vehicle human_11_3
#
# Step = 7995, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 7996, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 7997, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 7998, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 7999, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8000, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8001, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8002, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8003, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8004, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8005, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8006, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8007, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8008, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8009, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8010, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8011, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8012, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8013, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8014, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8015, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8016, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8017, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8018, Shock params: -1.7819390689140382, 2.4, 19 applied to vehicle human_11_0
#
# Step = 8162, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8163, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8164, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8165, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8166, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8167, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8168, Shock params: -1.3618223133360188, 0.7, 19 applied to vehicle human_11_6
#
# Step = 8328, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8329, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8330, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
# Step = 8331, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8332, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8333, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8334, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8335, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8336, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8337, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8338, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8339, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8340, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8341, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8342, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8343, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8344, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8345, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8346, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8347, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8348, Shock params: -1.4270455704181555, 2.1, 19 applied to vehicle human_11_1
#
# Step = 8495, Shock params: -1.3177941639269946, 0.5, 19 applied to vehicle human_11_5
#
# Step = 8496, Shock params: -1.3177941639269946, 0.5, 19 applied to vehicle human_11_5
#
# Step = 8497, Shock params: -1.3177941639269946, 0.5, 19 applied to vehicle human_11_5
#
# Step = 8498, Shock params: -1.3177941639269946, 0.5, 19 applied to vehicle human_11_5
#
# Step = 8499, Shock params: -1.3177941639269946, 0.5, 19 applied to vehicle human_11_5
#
# Round 0, Return: {'follower': [-2731544.8873474956]} for agent follower
#
# -----------------------
# ring length: 260
# v_max: 5.139779427502188
# -----------------------
# /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x/density_aware_multiagent_ring_20240328-1406571711649217.6614523-0_emission.csv /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x
#
# Directory: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/
#
# 2024-03-28 14:12:44,340	ERROR worker.py:679 -- Calling ray.init() again after it has already been called.
#
# Checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
#
# 2024-03-28 14:12:47,780	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:12:47,851	INFO trainable.py:346 -- Restored from checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
# 2024-03-28 14:12:47,851	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 4520000, '_time_total': 6542.175364017487, '_episodes_total': 998}
#
#
# Leader agent restored
# <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f11b8411ef0>
# Frequency: 13
# Intensity: -1.4700300377874103
# Duration: 2.0
# Intensity: -2.1260615844769704
# Duration: 1.1
# Intensity: -1.847201031955959
# Duration: 2.4
# Intensity: -2.611112118339902
# Duration: 1.7
# Intensity: -2.075599523752684
# Duration: 1.9
# Intensity: -1.6694776787930916
# Duration: 1.6
# Intensity: -1.8326684858234485
# Duration: 1.2
# Intensity: -2.893496904254388
# Duration: 1.4
# Intensity: -1.0418350391143474
# Duration: 0.7
# Intensity: -1.1121236743183283
# Duration: 1.6
# Intensity: -1.691912808873004
# Duration: 1.1
# Intensity: -2.550410490727062
# Duration: 1.5
# Intensity: -1.9204024745320567
# Duration: 1.2
# Durations:  [20. 11. 24. 17. 19. 16. 12. 14.  7. 16. 11. 15. 12.]
# Start times:  [5500 5749 5998 6247 6496 6745 6994 7243 7492 7741 7990 8239 8488]
# End times:  [5520.0, 5760.0, 6022.0, 6264.0, 6515.0, 6761.0, 7006.0, 7257.0, 7499.0, 7757.0, 8001.0, 8254.0, 8500.0]
# Shock times:
#  [[5500. 5520.]
#  [5749. 5760.]
#  [5998. 6022.]
#  [6247. 6264.]
#  [6496. 6515.]
#  [6745. 6761.]
#  [6994. 7006.]
#  [7243. 7257.]
#  [7492. 7499.]
#  [7741. 7757.]
#  [7990. 8001.]
#  [8239. 8254.]
#  [8488. 8500.]]
# Step = 5500, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5501, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5502, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5503, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5504, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5505, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5506, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5507, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5508, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5509, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5510, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5511, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5512, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5513, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5514, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5515, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5516, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5517, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5518, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5519, Shock params: -1.4700300377874103, 2.0, 13 applied to vehicle human_11_5
#
# Step = 5749, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5750, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5751, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5752, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5753, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5754, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5755, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5756, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5757, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5758, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5759, Shock params: -2.1260615844769704, 1.1, 13 applied to vehicle human_11_3
#
# Step = 5998, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 5999, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6000, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6001, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6002, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6003, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6004, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6005, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6006, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6007, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6008, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6009, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6010, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
# Step = 6011, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6012, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6013, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6014, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6015, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6016, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6017, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6018, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6019, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6020, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6021, Shock params: -1.847201031955959, 2.4, 13 applied to vehicle human_11_7
#
# Step = 6247, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6248, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6249, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6250, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6251, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6252, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6253, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6254, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6255, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6256, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6257, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6258, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6259, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6260, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6261, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6262, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6263, Shock params: -2.611112118339902, 1.7, 13 applied to vehicle human_11_5
#
# Step = 6496, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6497, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6498, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6499, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6500, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6501, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6502, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6503, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6504, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6505, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6506, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6507, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6508, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6509, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6510, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6511, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6512, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6513, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6514, Shock params: -2.075599523752684, 1.9, 13 applied to vehicle human_11_3
#
# Step = 6745, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6746, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6747, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6748, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6749, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6750, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6751, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6752, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6753, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6754, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6755, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6756, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6757, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6758, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6759, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6760, Shock params: -1.6694776787930916, 1.6, 13 applied to vehicle human_11_3
#
# Step = 6994, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 6995, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 6996, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 6997, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 6998, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 6999, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7000, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7001, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7002, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7003, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7004, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7005, Shock params: -1.8326684858234485, 1.2, 13 applied to vehicle human_11_8
#
# Step = 7243, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7244, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7245, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7246, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7247, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7248, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7249, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7250, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7251, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7252, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7253, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7254, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7255, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7256, Shock params: -2.893496904254388, 1.4, 13 applied to vehicle human_11_5
#
# Step = 7492, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7493, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7494, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7495, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7496, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7497, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
# Step = 7498, Shock params: -1.0418350391143474, 0.7, 13 applied to vehicle human_11_6
#
# Step = 7741, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7742, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7743, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7744, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7745, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7746, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7747, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7748, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7749, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7750, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7751, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7752, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7753, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7754, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7755, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7756, Shock params: -1.1121236743183283, 1.6, 13 applied to vehicle human_11_2
#
# Step = 7990, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7991, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7992, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7993, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7994, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7995, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7996, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7997, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7998, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 7999, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 8000, Shock params: -1.691912808873004, 1.1, 13 applied to vehicle human_11_8
#
# Step = 8239, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8240, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8241, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8242, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8243, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8244, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8245, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8246, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8247, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8248, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8249, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8250, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8251, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8252, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8253, Shock params: -2.550410490727062, 1.5, 13 applied to vehicle human_11_7
#
# Step = 8488, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8489, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8490, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8491, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8492, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8493, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8494, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8495, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8496, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8497, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8498, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Step = 8499, Shock params: -1.9204024745320567, 1.2, 13 applied to vehicle human_11_4
#
# Round 1, Return: {'follower': [-2763794.4410971664]} for agent follower
#
# -----------------------
# ring length: 260
# v_max: 5.139779427502188
# -----------------------
# /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x/density_aware_multiagent_ring_20240328-1412381711649558.5798147-0_emission.csv /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x
#
# Directory: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/
#
# 2024-03-28 14:18:29,160	ERROR worker.py:679 -- Calling ray.init() again after it has already been called.
#
# Checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
#
# 2024-03-28 14:18:32,565	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:18:32,643	INFO trainable.py:346 -- Restored from checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
# 2024-03-28 14:18:32,643	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 4520000, '_time_total': 6542.175364017487, '_episodes_total': 998}
#
#
# Leader agent restored
# <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f11b84a6ef0>
# Frequency: 17
# Intensity: -2.6234700928336547
# Duration: 1.2
# Intensity: -2.720001177228413
# Duration: 2.2
# Intensity: -2.7056581110236917
# Duration: 1.1
# Intensity: -2.5537565925504855
# Duration: 1.7
# Intensity: -2.689630620428924
# Duration: 2.1
# Intensity: -2.5672245973518013
# Duration: 2.1
# Intensity: -2.216319802544674
# Duration: 1.1
# Intensity: -1.0778096999462858
# Duration: 2.0
# Intensity: -1.0126661226722633
# Duration: 0.9
# Intensity: -2.040637787366873
# Duration: 1.1
# Intensity: -2.3151889798431897
# Duration: 2.0
# Intensity: -1.3962048920846337
# Duration: 0.6
# Intensity: -1.1190773338573394
# Duration: 0.7
# ...
#
# Step = 6074, Shock params: -1.4313102313762365, 1.5, 17 applied to vehicle human_11_4
#
# Step = 6247, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6248, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6249, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6250, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6251, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6252, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6253, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6254, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6255, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6256, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6257, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6258, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6259, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6260, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6261, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6262, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6263, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6264, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6265, Shock params: -2.393014981295282, 1.9, 17 applied to vehicle human_11_0
#
# Step = 6434, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6435, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6436, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6437, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6438, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6439, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6440, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6441, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6442, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6443, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6444, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6445, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6446, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6447, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6448, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6449, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6450, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6451, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6452, Shock params: -2.6588902056786035, 1.9, 17 applied to vehicle human_11_4
#
# Step = 6620, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6621, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6622, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6623, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6624, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6625, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6626, Shock params: -2.8197977420717013, 0.7, 17 applied to vehicle human_11_0
#
# Step = 6807, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6808, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6809, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6810, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6811, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6812, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6813, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6814, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6815, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6816, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6817, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6818, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6819, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6820, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6821, Shock params: -2.677510913051088, 1.5, 17 applied to vehicle human_11_5
#
# Step = 6994, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 6995, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 6996, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 6997, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 6998, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
# Step = 6999, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7000, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7001, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7002, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7003, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7004, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7005, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7006, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7007, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7008, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7009, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7010, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7011, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7012, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7013, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7014, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7015, Shock params: -2.4464608244528856, 2.2, 17 applied to vehicle human_11_3
#
# Step = 7181, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7182, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7183, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7184, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7185, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7186, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7187, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7188, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7189, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7190, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7191, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7192, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7193, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7194, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7195, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7196, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7197, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7198, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7199, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7200, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7201, Shock params: -2.954001844897123, 2.1, 17 applied to vehicle human_11_7
#
# Step = 7368, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7369, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7370, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7371, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7372, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7373, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7374, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7375, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7376, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7377, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7378, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7379, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7380, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7381, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7382, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7383, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7384, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7385, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7386, Shock params: -1.886038068278181, 1.9, 17 applied to vehicle human_11_3
#
# Step = 7554, Shock params: -1.0057289254737918, 0.2, 17 applied to vehicle human_11_7
#
# Step = 7555, Shock params: -1.0057289254737918, 0.2, 17 applied to vehicle human_11_7
#
# Step = 7741, Shock params: -1.101079163715729, 0.2, 17 applied to vehicle human_11_8
#
# Step = 7742, Shock params: -1.101079163715729, 0.2, 17 applied to vehicle human_11_8
#
# Step = 7928, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7929, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7930, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7931, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7932, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7933, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7934, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7935, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7936, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7937, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 7938, Shock params: -2.219450243969891, 1.1, 17 applied to vehicle human_11_3
#
# Step = 8115, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8116, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8117, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8118, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8119, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8120, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8121, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8122, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8123, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8124, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8125, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8126, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8127, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8128, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8129, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8130, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8131, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8132, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8133, Shock params: -1.7761367922881472, 1.9, 17 applied to vehicle human_11_6
#
# Step = 8302, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8303, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8304, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8305, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8306, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8307, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
# Step = 8308, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8309, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8310, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8311, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8312, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8313, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8314, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8315, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8316, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8317, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8318, Shock params: -2.4149687126841677, 1.7, 17 applied to vehicle human_11_8
#
# Step = 8489, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8490, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8491, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8492, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8493, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8494, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8495, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8496, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8497, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8498, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
#
# Step = 8499, Shock params: -1.739555218126484, 1.1, 17 applied to vehicle human_11_5
