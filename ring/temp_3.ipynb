# %%
# set parameters here
NUM_ROLLOUTS = 5
LENGTH = 260
NUM_CONTROLLED = 13

# %%
#### Efficiency ####
# Make sure to set the efficiency to true at test time in the controller file and have those files at exp_configs
# Make sure to have the right leader
# !python test_rllib.py ./Ours/Trained_policies/60_percent/PPO_MultiAgentDensityAwareRLEnv-v1_ed546dfe_2024-02-14_17-18-06nijs5agx 200\
--method ours13x --length $LENGTH --num_rollouts 20 --render --gen_emission --shock --num_controlled $NUM_CONTROLLED
# Out:
# 2024-03-28 14:06:49,971	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2024-03-28 14:06:49,971	INFO resource_spec.py:216 -- Starting Ray with 32.08 GiB memory available for workers and up to 16.05 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2024-03-28 14:06:51,668	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2024-03-28 14:06:51,673	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2024-03-28 14:06:54,419	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:06:54,473	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/Trained_policies/60_percent/PPO_MultiAgentDensityAwareRLEnv-v1_ed546dfe_2024-02-14_17-18-06nijs5agx/checkpoint_200/checkpoint-200
# 2024-03-28 14:06:54,473	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 9000000, '_time_total': 30950.06327533722, '_episodes_total': 1998}
#
# -----------------------
# ring length: 260
# v_max: 5.139779427502188
# -----------------------
#
# Directory: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/
#
# 2024-03-28 14:06:58,247	ERROR worker.py:679 -- Calling ray.init() again after it has already been called.
#
# Checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
#
# 2024-03-28 14:07:01,030	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:07:01,067	INFO trainable.py:346 -- Restored from checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
# 2024-03-28 14:07:01,067	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 4520000, '_time_total': 6542.175364017487, '_episodes_total': 998}
#
#
# Leader agent restored
# <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f94d78f0a90>
# Frequency: 29
# Intensity: -2.5493433195869586
# Duration: 1.9
# Intensity: -1.3658278913281254
# Duration: 0.7
# Intensity: -1.1767161938349622
# Duration: 1.0
# Intensity: -2.9871080380407453
# Duration: 1.5
# Intensity: -2.6832824657607244
# Duration: 1.6
# Intensity: -2.7343625664302493
# Duration: 2.4
# Intensity: -1.8657581792220892
# Duration: 0.5
# Intensity: -2.7130830659650527
# Duration: 1.9
# Intensity: -1.6887307369085707
# Duration: 0.6
# Intensity: -2.548388201277036
# Duration: 1.1
# Intensity: -2.9725391747678134
# Duration: 2.2
# Intensity: -1.197462783386732
# Duration: 1.9
# Intensity: -1.2393767871378274
# Duration: 0.9
# Intensity: -1.551010916757888
# Duration: 0.5
# Intensity: -2.242552908074011
# Duration: 1.5
# Intensity: -1.9699732380594983
# Duration: 0.9
# Intensity: -2.7877989561066023
# Duration: 2.2
# Intensity: -2.7791643478540995
# Duration: 1.9
# Intensity: -1.5973739702486593
# Duration: 1.5
# Intensity: -1.8574100060225365
# Duration: 0.7
# Intensity: -1.2444251001082423
# Duration: 0.2
# Intensity: -2.272457421806938
# Duration: 0.7
# Intensity: -1.61087152700147
# Duration: 1.2
# Intensity: -2.136889017504272
# Duration: 0.9
# Intensity: -2.6184693682648374
# Duration: 1.6
# Intensity: -1.0375102918451105
# Duration: 0.9
# Intensity: -2.5592265815829887
# Duration: 1.2
# Intensity: -2.555938855535488
# Duration: 2.0
# Intensity: -1.918815337444881
# Duration: 1.7
# Durations:  [19.  7. 10. 15. 16. 24.  5. 19.  6. 11. 22. 19.  9.  5. 15.  9. 22. 19.
#  15.  7.  2.  7. 12.  9. 16.  9. 12. 20. 17.]
# Start times:  [5500 5606 5713 5819 5926 6032 6139 6245 6352 6458 6565 6671 6778 6884
#  6991 7098 7204 7311 7417 7524 7630 7737 7843 7950 8056 8163 8269 8376
#  8483]
# End times:  [5519.0, 5613.0, 5723.0, 5834.0, 5942.0, 6056.0, 6144.0, 6264.0, 6358.0, 6469.0, 6587.0, 6690.0, 6787.0, 6889.0, 7006.0, 7107.0, 7226.0, 7330.0, 7432.0, 7531.0, 7632.0, 7744.0, 7855.0, 7959.0, 8072.0, 8172.0, 8281.0, 8396.0, 8500.0]
# Shock times:
#  [[5500. 5519.]
#  [5606. 5613.]
#  [5713. 5723.]
#  [5819. 5834.]
#  [5926. 5942.]
#  [6032. 6056.]
#  [6139. 6144.]
#  [6245. 6264.]
#  [6352. 6358.]
#  [6458. 6469.]
#  [6565. 6587.]
#  [6671. 6690.]
#  [6778. 6787.]
#  [6884. 6889.]
#  [6991. 7006.]
#  [7098. 7107.]
#  [7204. 7226.]
#  [7311. 7330.]
#  [7417. 7432.]
#  [7524. 7531.]
#  [7630. 7632.]
#  [7737. 7744.]
#  [7843. 7855.]
#  [7950. 7959.]
#  [8056. 8072.]
#  [8163. 8172.]
#  [8269. 8281.]
#  [8376. 8396.]
#  [8483. 8500.]]
# Step = 5500, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5501, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5502, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5503, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5504, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5505, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5506, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5507, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5508, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5509, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5510, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5511, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5512, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5513, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5514, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5515, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5516, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5517, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5518, Shock params: -2.5493433195869586, 1.9, 29 applied to vehicle human_11_6
#
# Step = 5606, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5607, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5608, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5609, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5610, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5611, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5612, Shock params: -1.3658278913281254, 0.7, 29 applied to vehicle human_11_2
#
# Step = 5713, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5714, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5715, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5716, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5717, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5718, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5719, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5720, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5721, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5722, Shock params: -1.1767161938349622, 1.0, 29 applied to vehicle human_11_6
#
# Step = 5819, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5820, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5821, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5822, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5823, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5824, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5825, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5826, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
# Step = 5827, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5828, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5829, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5830, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5831, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5832, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5833, Shock params: -2.9871080380407453, 1.5, 29 applied to vehicle human_11_7
#
# Step = 5926, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5927, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5928, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5929, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5930, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5931, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5932, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5933, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5934, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5935, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5936, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5937, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5938, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5939, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5940, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 5941, Shock params: -2.6832824657607244, 1.6, 29 applied to vehicle human_11_8
#
# Step = 6032, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6033, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6034, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6035, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6036, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6037, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6038, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6039, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6040, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6041, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6042, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6043, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6044, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6045, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6046, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6047, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6048, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6049, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6050, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6051, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6052, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6053, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6054, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6055, Shock params: -2.7343625664302493, 2.4, 29 applied to vehicle human_11_1
#
# Step = 6139, Shock params: -1.8657581792220892, 0.5, 29 applied to vehicle human_11_0
#
# Step = 6140, Shock params: -1.8657581792220892, 0.5, 29 applied to vehicle human_11_0
#
# Step = 6141, Shock params: -1.8657581792220892, 0.5, 29 applied to vehicle human_11_0
#
# Step = 6142, Shock params: -1.8657581792220892, 0.5, 29 applied to vehicle human_11_0
#
# Step = 6143, Shock params: -1.8657581792220892, 0.5, 29 applied to vehicle human_11_0
#
# Step = 6245, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6246, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6247, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6248, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6249, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6250, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6251, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6252, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6253, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6254, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6255, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6256, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6257, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6258, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6259, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6260, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6261, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6262, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6263, Shock params: -2.7130830659650527, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6352, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6353, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6354, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6355, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6356, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6357, Shock params: -1.6887307369085707, 0.6, 29 applied to vehicle human_11_1
#
# Step = 6458, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6459, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6460, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6461, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6462, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6463, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6464, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6465, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6466, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6467, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6468, Shock params: -2.548388201277036, 1.1, 29 applied to vehicle human_11_0
#
# Step = 6565, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6566, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6567, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6568, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6569, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6570, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6571, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
# Step = 6572, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6573, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6574, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6575, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6576, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6577, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6578, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6579, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6580, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6581, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6582, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6583, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6584, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6585, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6586, Shock params: -2.9725391747678134, 2.2, 29 applied to vehicle human_11_1
#
# Step = 6671, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6672, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6673, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6674, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6675, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6676, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6677, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6678, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6679, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6680, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6681, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6682, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6683, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6684, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6685, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6686, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6687, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6688, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6689, Shock params: -1.197462783386732, 1.9, 29 applied to vehicle human_11_5
#
# Step = 6778, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6779, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6780, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6781, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6782, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6783, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6784, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6785, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6786, Shock params: -1.2393767871378274, 0.9, 29 applied to vehicle human_11_5
#
# Step = 6884, Shock params: -1.551010916757888, 0.5, 29 applied to vehicle human_11_4
#
# Step = 6885, Shock params: -1.551010916757888, 0.5, 29 applied to vehicle human_11_4
#
# Step = 6886, Shock params: -1.551010916757888, 0.5, 29 applied to vehicle human_11_4
#
# Step = 6887, Shock params: -1.551010916757888, 0.5, 29 applied to vehicle human_11_4
#
# Step = 6888, Shock params: -1.551010916757888, 0.5, 29 applied to vehicle human_11_4
#
# Step = 6991, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6992, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6993, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6994, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6995, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6996, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6997, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6998, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 6999, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7000, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7001, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7002, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7003, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7004, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7005, Shock params: -2.242552908074011, 1.5, 29 applied to vehicle human_11_2
#
# Step = 7098, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7099, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7100, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7101, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7102, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7103, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7104, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7105, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7106, Shock params: -1.9699732380594983, 0.9, 29 applied to vehicle human_11_7
#
# Step = 7204, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7205, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7206, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7207, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7208, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7209, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7210, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7211, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7212, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7213, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7214, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7215, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7216, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7217, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7218, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7219, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7220, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7221, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7222, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7223, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7224, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7225, Shock params: -2.7877989561066023, 2.2, 29 applied to vehicle human_11_3
#
# Step = 7311, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7312, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7313, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
# Step = 7314, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7315, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7316, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7317, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7318, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7319, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7320, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7321, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7322, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7323, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7324, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7325, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7326, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7327, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7328, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7329, Shock params: -2.7791643478540995, 1.9, 29 applied to vehicle human_11_5
#
# Step = 7417, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7418, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7419, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7420, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7421, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7422, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7423, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7424, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7425, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7426, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7427, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7428, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7429, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7430, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7431, Shock params: -1.5973739702486593, 1.5, 29 applied to vehicle human_11_6
#
# Step = 7524, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7525, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7526, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7527, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7528, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7529, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7530, Shock params: -1.8574100060225365, 0.7, 29 applied to vehicle human_11_1
#
# Step = 7630, Shock params: -1.2444251001082423, 0.2, 29 applied to vehicle human_11_5
#
# Step = 7631, Shock params: -1.2444251001082423, 0.2, 29 applied to vehicle human_11_5
#
# Step = 7737, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7738, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7739, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7740, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7741, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7742, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7743, Shock params: -2.272457421806938, 0.7, 29 applied to vehicle human_11_5
#
# Step = 7843, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7844, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7845, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7846, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7847, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7848, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7849, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7850, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7851, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7852, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7853, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7854, Shock params: -1.61087152700147, 1.2, 29 applied to vehicle human_11_0
#
# Step = 7950, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7951, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7952, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7953, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7954, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7955, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7956, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7957, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 7958, Shock params: -2.136889017504272, 0.9, 29 applied to vehicle human_11_8
#
# Step = 8056, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8057, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8058, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8059, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8060, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8061, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8062, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8063, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8064, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8065, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8066, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8067, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8068, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8069, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8070, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8071, Shock params: -2.6184693682648374, 1.6, 29 applied to vehicle human_11_3
#
# Step = 8163, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8164, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8165, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8166, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8167, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8168, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8169, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8170, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8171, Shock params: -1.0375102918451105, 0.9, 29 applied to vehicle human_11_2
#
# Step = 8269, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8270, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
# Step = 8271, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8272, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8273, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8274, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8275, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8276, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8277, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8278, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8279, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8280, Shock params: -2.5592265815829887, 1.2, 29 applied to vehicle human_11_5
#
# Step = 8376, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8377, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8378, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8379, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8380, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8381, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8382, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8383, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8384, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8385, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8386, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8387, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8388, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8389, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8390, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8391, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8392, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8393, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8394, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8395, Shock params: -2.555938855535488, 2.0, 29 applied to vehicle human_11_1
#
# Step = 8483, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8484, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8485, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8486, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8487, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8488, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8489, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8490, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8491, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8492, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8493, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8494, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8495, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8496, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8497, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8498, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Step = 8499, Shock params: -1.918815337444881, 1.7, 29 applied to vehicle human_11_1
#
# Round 0, Return: {'follower': [-2739196.1588468878]} for agent follower
#
# -----------------------
# ring length: 260
# v_max: 5.139779427502188
# -----------------------
# /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x/density_aware_multiagent_ring_20240328-1406551711649215.6147149-0_emission.csv /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/test_time_rollout/ours13x
#
# Directory: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/
#
# 2024-03-28 14:12:38,876	ERROR worker.py:679 -- Calling ray.init() again after it has already been called.
#
# Checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
#
# 2024-03-28 14:12:41,757	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2024-03-28 14:12:41,798	INFO trainable.py:346 -- Restored from checkpoint: /mnt/c/Users/09_gi/Desktop/Imitation_Congestion/ring/Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4/checkpoint_200/checkpoint-200
# 2024-03-28 14:12:41,798	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 200, '_timesteps_total': 4520000, '_time_total': 6542.175364017487, '_episodes_total': 998}
#
#
# Leader agent restored
# <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f8ffcf443c8>
# Frequency: 21
# Intensity: -2.8472800434755454
# Duration: 1.2
# Intensity: -1.0317962058806134
# Duration: 1.0
# Intensity: -2.7034288885866067
# Duration: 1.5
# Intensity: -2.4257461455128464
# Duration: 1.1
# Intensity: -2.67287311878846
# Duration: 0.7
# Intensity: -1.9982654341491841
# Duration: 1.1
# Intensity: -1.9705895485938847
# Duration: 1.5
# Intensity: -1.5345647926290247
# Duration: 1.7
# Intensity: -1.4511161078454056
# Duration: 0.2
# Intensity: -1.2756261719529887
# Duration: 1.4
# Intensity: -2.0753723353609996
# Duration: 1.5
# Intensity: -1.3844291341099717
# Duration: 2.0
# Intensity: -2.336355390719542
# Duration: 1.1
# Intensity: -2.6128453001769683
# Duration: 2.0
# Intensity: -2.6396368265168197
# Duration: 2.0
# Intensity: -1.2849354802875281
# Duration: 1.1
# Intensity: -2.6281163619198757
# Duration: 1.5
# Intensity: -1.1622942850379474
# Duration: 0.5
# Intensity: -1.679671764611714
# Duration: 0.5
# Intensity: -1.093455966651212
# Duration: 1.7
# Intensity: -2.8897195564577505
# Duration: 1.1
# Durations:  [12. 10. 15. 11.  7. 11. 15. 17.  2. 14. 15. 20. 11. 20. 20. 11. 15.  5.
#   5. 17. 11.]
# Start times:  [5500 5649 5798 5948 6097 6247 6396 6546 6695 6845 6994 7143 7293 7442
#  7592 7741 7891 8040 8190 8339 8489]
# End times:  [5512.0, 5659.0, 5813.0, 5959.0, 6104.0, 6258.0, 6411.0, 6563.0, 6697.0, 6859.0, 7009.0, 7163.0, 7304.0, 7462.0, 7612.0, 7752.0, 7906.0, 8045.0, 8195.0, 8356.0, 8500.0]
# Shock times:
#  [[5500. 5512.]
#  [5649. 5659.]
#  [5798. 5813.]
#  [5948. 5959.]
#  [6097. 6104.]
#  [6247. 6258.]
#  [6396. 6411.]
#  [6546. 6563.]
#  [6695. 6697.]
#  [6845. 6859.]
#  [6994. 7009.]
#  [7143. 7163.]
#  [7293. 7304.]
#  [7442. 7462.]
#  [7592. 7612.]
#  [7741. 7752.]
#  [7891. 7906.]
#  [8040. 8045.]
#  [8190. 8195.]
#  [8339. 8356.]
#  [8489. 8500.]]
# Step = 5500, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5501, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5502, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5503, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5504, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5505, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5506, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5507, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5508, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5509, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5510, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
#
# Step = 5511, Shock params: -2.8472800434755454, 1.2, 21 applied to vehicle human_11_6
# Step = 5649, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5650, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5651, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5652, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5653, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5654, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5655, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5656, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5657, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5658, Shock params: -1.0317962058806134, 1.0, 21 applied to vehicle human_11_5
#
# Step = 5798, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5799, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5800, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5801, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5802, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5803, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5804, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5805, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5806, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5807, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5808, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5809, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5810, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5811, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5812, Shock params: -2.7034288885866067, 1.5, 21 applied to vehicle human_11_2
#
# Step = 5948, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5949, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5950, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5951, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5952, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5953, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5954, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5955, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5956, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5957, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 5958, Shock params: -2.4257461455128464, 1.1, 21 applied to vehicle human_11_1
#
# Step = 6097, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6098, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6099, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6100, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6101, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6102, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6103, Shock params: -2.67287311878846, 0.7, 21 applied to vehicle human_11_6
#
# Step = 6247, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6248, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6249, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6250, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6251, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6252, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6253, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6254, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6255, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6256, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6257, Shock params: -1.9982654341491841, 1.1, 21 applied to vehicle human_11_6
#
# Step = 6396, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6397, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6398, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6399, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6400, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6401, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6402, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6403, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6404, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6405, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6406, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6407, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6408, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6409, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6410, Shock params: -1.9705895485938847, 1.5, 21 applied to vehicle human_11_7
#
# Step = 6546, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# Step = 6547, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# Step = 6548, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# Step = 6549, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# Step = 6550, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# Step = 6551, Shock params: -1.5345647926290247, 1.7, 21 applied to vehicle human_11_8
#
# ...
#
# Step = 5901, Shock params: -1.0495617107359552, 0.4, 16 applied to vehicle human_11_3
#
# Step = 5902, Shock params: -1.0495617107359552, 0.4, 16 applied to vehicle human_11_3
#
# Step = 6098, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6099, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6100, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6101, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6102, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6103, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6104, Shock params: -1.7483675031722428, 0.7, 16 applied to vehicle human_11_6
#
# Step = 6298, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6299, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6300, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6301, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6302, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6303, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
# Step = 6304, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6305, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6306, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6307, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6308, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6309, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6310, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6311, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6312, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6313, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6314, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6315, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6316, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6317, Shock params: -2.3330384686244496, 2.0, 16 applied to vehicle human_11_3
#
# Step = 6498, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6499, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6500, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6501, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6502, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6503, Shock params: -1.5937942451509217, 0.6, 16 applied to vehicle human_11_8
#
# Step = 6697, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6698, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6699, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6700, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6701, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6702, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6703, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6704, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6705, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6706, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6707, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6708, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6709, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6710, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6711, Shock params: -2.2895346969303647, 1.5, 16 applied to vehicle human_11_1
#
# Step = 6897, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6898, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6899, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6900, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6901, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6902, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6903, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6904, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6905, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6906, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 6907, Shock params: -1.013110142366662, 1.1, 16 applied to vehicle human_11_2
#
# Step = 7096, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7097, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7098, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7099, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7100, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7101, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7102, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7103, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7104, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7105, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7106, Shock params: -1.9711520218400398, 1.1, 16 applied to vehicle human_11_8
#
# Step = 7296, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7297, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7298, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7299, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7300, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7301, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7302, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7303, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7304, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7305, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7306, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7307, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7308, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7309, Shock params: -2.912574949252938, 1.4, 16 applied to vehicle human_11_7
#
# Step = 7496, Shock params: -1.1624450237527542, 0.5, 16 applied to vehicle human_11_2
#
# Step = 7497, Shock params: -1.1624450237527542, 0.5, 16 applied to vehicle human_11_2
#
# Step = 7498, Shock params: -1.1624450237527542, 0.5, 16 applied to vehicle human_11_2
#
# Step = 7499, Shock params: -1.1624450237527542, 0.5, 16 applied to vehicle human_11_2
#
# Step = 7500, Shock params: -1.1624450237527542, 0.5, 16 applied to vehicle human_11_2
#
# Step = 7695, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7696, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7697, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7698, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7699, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7700, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7701, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7702, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7703, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7704, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7705, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7706, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7707, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7708, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7709, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7710, Shock params: -1.357215446285408, 1.6, 16 applied to vehicle human_11_8
#
# Step = 7895, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7896, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7897, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7898, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
# Step = 7899, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7900, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7901, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7902, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7903, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7904, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7905, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7906, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7907, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7908, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 7909, Shock params: -2.151079505204834, 1.5, 16 applied to vehicle human_11_6
#
# Step = 8094, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8095, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8096, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8097, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8098, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8099, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8100, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8101, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8102, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8103, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8104, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8105, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8106, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8107, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8108, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8109, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8110, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8111, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8112, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8113, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8114, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8115, Shock params: -2.6304248584540018, 2.2, 16 applied to vehicle human_11_8
#
# Step = 8294, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8295, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8296, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8297, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8298, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8299, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8300, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8301, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8302, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8303, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8304, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8305, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8306, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8307, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8308, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8309, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8310, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8311, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8312, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8313, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8314, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8315, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8316, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8317, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8318, Shock params: -2.951430025394491, 2.5, 16 applied to vehicle human_11_6
#
# Step = 8494, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# Step = 8495, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# Step = 8496, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# Step = 8497, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# Step = 8498, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# Step = 8499, Shock params: -1.5383112251099265, 0.6, 16 applied to vehicle human_11_6
#
# ^C
# Traceback (most recent call last):
#   File "test_rllib.py", line 539, in <module>
#     visualizer_rllib(args)
#   File "test_rllib.py", line 336, in visualizer_rllib
#     state, reward, done, _ = env.step(action)
#   File "/mnt/c/Users/09_gi/Desktop/Imitation_Congestion/flow/envs/multiagent/base.py", line 95, in step
#     self.k.update(reset=False)
#   File "/mnt/c/Users/09_gi/Desktop/Imitation_Congestion/flow/core/kernel/kernel.py", line 104, in update
#     self.simulation.update(reset)
#   File "/mnt/c/Users/09_gi/Desktop/Imitation_Congestion/flow/core/kernel/simulation/traci.py", line 128, in update
#     "leader_id": kv.get_leader(veh_id),
#   File "/mnt/c/Users/09_gi/Desktop/Imitation_Congestion/flow/core/kernel/vehicle/traci.py", line 610, in get_leader
#     if isinstance(veh_id, (list, np.ndarray)):
# KeyboardInterrupt
