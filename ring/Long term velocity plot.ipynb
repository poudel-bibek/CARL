# %% [markdown]
# ### Long term stability plot
# - Total time: 1 hour (3x than regular)
# - Shock time: 30 minutes (5x than regular)

# %%
# set parameters here
NUM_ROLLOUTS = 5
LENGTH = 260
SHOCK_START_TIME = 10000 
SHOCK_END_TIME = 28000 #1800 seconds of shock 
WARMUP = 4000
HORIZON = 32000 # 1 hour total this excludes warmup (32000 + 4000 = 36000)

# %% [markdown]
# ### Wu

# %%
# For CAV (first get the data)
# !python test_rllib.py ./Wu_et_al/Trained_policies/5_percent/PPO_WaveAttenuationPOEnv-v0_25b5cb6e_2022-01-26_10-58-12e9f4i3ao 50 \
--method wu --length $LENGTH --warmup $WARMUP --horizon $HORIZON --shock_start_time $SHOCK_START_TIME --shock_end_time $SHOCK_END_TIME\
--num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render --num_controlled 1

# %%
# For CAV
# !python eval_metrics.py --method wu --save_plots --horizon $HORIZON --warmup $WARMUP \
--start_time $SHOCK_START_TIME --end_time $SHOCK_END_TIME --num_rollouts $NUM_ROLLOUTS
# Out:
# Calculating metrics for 5 rollouts on files:
# ['./test_time_rollout/wu/stabilizing_the_ring_20240522-1055091716389709.884241-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1100251716390025.0237758-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1105551716390355.5843444-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1111221716390682.0654545-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1116401716391000.9775944-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1141361716392496.919521-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1147341716392854.7747838-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1153251716393205.9664829-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1159351716393575.5796177-0_emission.csv', './test_time_rollout/wu/stabilizing_the_ring_20240522-1205441716393944.2697668-0_emission.csv']
#
# Vehicle ids: ['human_0' 'human_1' 'human_2' 'human_3' 'human_4' 'human_5' 'human_6'
#  'human_7' 'human_8' 'human_9' 'human_10' 'human_11' 'human_12' 'human_13'
#  'human_14' 'human_15' 'human_16' 'human_17' 'human_18' 'human_19'
#  'human_20' 'rl_0']
#
# (1, 11311)
# Worst case time to collision for each vehicle (s):
# [-1.75554256]
#
# Best case time to collision for each vehicle (s):
# [-898350.5262249]
#
# Average time to collision for each vehicle (s):
# [-278.86031024]
#
# Standard deviation of time to collision for each vehicle (s):
# [8994.22099618]
#
# Time to Collision (s):
# 	Worst= -1.76
# 	Best= -898350.53
# 	Average= -278.86
# 	Std= 8994.22
#
# ####################
# (1, 11311)
# Worst case drac for each vehicle (m/s^2):
# [1.96273337]
#
# DRAC (m/s^2):
# 	Worst= 1.96
#
# (1, 12142)
# Worst case time to collision for each vehicle (s):
# [-2.06356515]
#
# Best case time to collision for each vehicle (s):
# [-113009.63377514]
#
# Average time to collision for each vehicle (s):
# [-170.42053776]
#
# Standard deviation of time to collision for each vehicle (s):
# [1990.53141555]
#
# Time to Collision (s):
# 	Worst= -2.06
# 	Best= -113009.63
# 	Average= -170.42
# 	Std= 1990.53
#
# ####################
# (1, 12142)
# Worst case drac for each vehicle (m/s^2):
# [1.5745201]
#
# DRAC (m/s^2):
# 	Worst= 1.57
#
# (1, 11707)
# Worst case time to collision for each vehicle (s):
# [-1.80222884]
#
# Best case time to collision for each vehicle (s):
# [-15739015.43875946]
#
# Average time to collision for each vehicle (s):
# [-1538.57669879]
#
# Standard deviation of time to collision for each vehicle (s):
# [145486.60742024]
#
# Time to Collision (s):
# 	Worst= -1.8
# 	Best= -15739015.44
# 	Average= -1538.58
# 	Std= 145486.61
#
# ####################
# (1, 11707)
# Worst case drac for each vehicle (m/s^2):
# [1.88716037]
#
# DRAC (m/s^2):
# 	Worst= 1.89
#
# (1, 11669)
# Worst case time to collision for each vehicle (s):
# [-1.74260056]
#
# Best case time to collision for each vehicle (s):
# [-220705.23423639]
#
# Average time to collision for each vehicle (s):
# [-176.14120275]
#
# Standard deviation of time to collision for each vehicle (s):
# [2634.63694204]
#
# Time to Collision (s):
# 	Worst= -1.74
# 	Best= -220705.23
# 	Average= -176.14
# 	Std= 2634.64
#
# ####################
# (1, 11669)
# Worst case drac for each vehicle (m/s^2):
# [2.02217019]
#
# DRAC (m/s^2):
# 	Worst= 2.02
#
# (1, 11498)
# Worst case time to collision for each vehicle (s):
# [-2.04554703]
#
# Best case time to collision for each vehicle (s):
# [-77358.26699648]
#
# Average time to collision for each vehicle (s):
# [-123.3622148]
#
# Standard deviation of time to collision for each vehicle (s):
# [1077.52696227]
#
# Time to Collision (s):
# 	Worst= -2.05
# 	Best= -77358.27
# 	Average= -123.36
# 	Std= 1077.53
#
# ####################
# (1, 11498)
# Worst case drac for each vehicle (m/s^2):
# [1.48603768]
#
# DRAC (m/s^2):
# 	Worst= 1.49
#
# (1, 11297)
# Worst case time to collision for each vehicle (s):
# [-1.72433765]
#
# Best case time to collision for each vehicle (s):
# [-1.10990169e+17]
#
# Average time to collision for each vehicle (s):
# [-9.92299496e+12]
#
# Standard deviation of time to collision for each vehicle (s):
# [1.04425035e+15]
#
# Time to Collision (s):
# 	Worst= -1.72
# 	Best= -1.1099016881135942e+17
# 	Average= -9922994964011.32
# 	Std= 1044250347525947.2
#
# ####################
# (1, 11297)
# Worst case drac for each vehicle (m/s^2):
# [2.04900653]
#
# DRAC (m/s^2):
# 	Worst= 2.05
#
# (1, 11821)
# Worst case time to collision for each vehicle (s):
# [-1.73507615]
#
# Best case time to collision for each vehicle (s):
# [-9.93334759e+08]
#
# Average time to collision for each vehicle (s):
# [-85239.55806016]
#
# Standard deviation of time to collision for each vehicle (s):
# [9136324.98089319]
#
# Time to Collision (s):
# 	Worst= -1.74
# 	Best= -993334758.81
# 	Average= -85239.56
# 	Std= 9136324.98
#
# ####################
# (1, 11821)
# Worst case drac for each vehicle (m/s^2):
# [2.1218937]
#
# DRAC (m/s^2):
# 	Worst= 2.12
#
# (1, 11346)
# Worst case time to collision for each vehicle (s):
# [-1.88785309]
#
# Best case time to collision for each vehicle (s):
# [-1.08221327e+17]
#
# Average time to collision for each vehicle (s):
# [-9.8439751e+12]
#
# Standard deviation of time to collision for each vehicle (s):
# [1.01623897e+15]
#
# Time to Collision (s):
# 	Worst= -1.89
# 	Best= -1.0822132726815544e+17
# 	Average= -9843975101162.64
# 	Std= 1016238973301756.8
#
# ####################
# (1, 11346)
# Worst case drac for each vehicle (m/s^2):
# [1.77841022]
#
# DRAC (m/s^2):
# 	Worst= 1.78
#
# (1, 11443)
# Worst case time to collision for each vehicle (s):
# [-1.80868318]
#
# Best case time to collision for each vehicle (s):
# [-2236664.03099362]
#
# Average time to collision for each vehicle (s):
# [-352.51681303]
#
# Standard deviation of time to collision for each vehicle (s):
# [20978.88957448]
#
# Time to Collision (s):
# 	Worst= -1.81
# 	Best= -2236664.03
# 	Average= -352.52
# 	Std= 20978.89
#
# ####################
# (1, 11443)
# Worst case drac for each vehicle (m/s^2):
# [1.9113632]
#
# DRAC (m/s^2):
# 	Worst= 1.91
#
# (1, 11270)
# Worst case time to collision for each vehicle (s):
# [-1.90146258]
#
# Best case time to collision for each vehicle (s):
# [-42719.86765275]
#
# Average time to collision for each vehicle (s):
# [-125.76791222]
#
# Standard deviation of time to collision for each vehicle (s):
# [972.09808494]
#
# Time to Collision (s):
# 	Worst= -1.9
# 	Best= -42719.87
# 	Average= -125.77
# 	Std= 972.1
#
# ####################
# (1, 11270)
# Worst case drac for each vehicle (m/s^2):
# [2.19706179]
#
# DRAC (m/s^2):
# 	Worst= 2.2
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [9.42769187 9.40577132 9.36248676 9.2986217  9.33699503 9.30124765
#  9.26468088 9.19889306 9.08054343 8.95745928 8.94546191 8.85478452
#  8.82793787 8.71131457 8.71300215 8.66931659 8.56140176 8.41505464
#  8.24289409 8.15394332 8.03558953 8.46962948]
#
# Miles per gallon (mpg): Average= 8.87, std = 0.42
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.14832731 3.14778338 3.1472608  3.14661904 3.14587943 3.14506376
#  3.14421057 3.14340924 3.14264377 3.14188042 3.14103262 3.14022561
#  3.13941701 3.13867864 3.13794664 3.13714277 3.1360344  3.13401649
#  3.1355121  3.13490582 3.13429066 3.13373134]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.83396685 1.81690523 1.78879367 1.7627     1.73658301 1.71079381
#  1.68887965 1.65406074 1.61998672 1.56742526 1.53665632 1.48740992
#  1.47063875 1.43568054 1.38472318 1.36889899 1.35491482 1.3313511
#  1.30368954 1.27987981 1.23445189 1.20733907]
#
# Speed of all vehicles (m/s): Average= 3.14, std=1.53
#
# ####################
# Total number of vehicles that crossed the zero point: 476
#
# Flow (veh/hour): 952.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [11.19288609 11.14158168 11.08400397 10.95234723 10.84081839 10.71508499
#  10.6162589  10.47851857 10.38891696 10.28536091 10.14256672 10.06532891
#   9.99143521  9.90936727  9.87494741  9.83857821  9.81545325  9.75557283
#   9.67117172  9.58846385  9.46416114  9.59103781]
#
# Miles per gallon (mpg): Average= 10.25, std = 0.54
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.70941035 3.70820256 3.70755356 3.70753591 3.70829322 3.70974855
#  3.71216538 3.71534428 3.71897218 3.72258844 3.72528474 3.7267197
#  3.72698187 3.72650523 3.72555216 3.72420531 3.7224938  3.72033818
#  3.71792159 3.71536526 3.71273128 3.70998705]
# Standard deviation of speed of each vehicle (m/s):
# [1.47795032 1.44692336 1.4217568  1.37423379 1.33738111 1.30139478
#  1.26881952 1.23771425 1.21533678 1.19737393 1.16373663 1.13503142
#  1.1026817  1.08405297 1.06234574 1.0500633  1.03820096 1.02789969
#  0.99138382 0.9694069  0.96303552 0.95058694]
#
# Speed of all vehicles (m/s): Average= 3.72, std=1.17
#
# ####################
# Total number of vehicles that crossed the zero point: 564
#
# Flow (veh/hour): 1128.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [10.65941842 10.60510675 10.45182152 10.4014684  10.29500012 10.22555028
#  10.18648773 10.146324   10.04606241  9.95222608  9.85002776  9.74862055
#   9.68727886  9.65106847  9.60014569  9.47974273  9.38810757  9.27546828
#   9.07895137  8.96510361  8.84977076  9.17758727]
#
# Miles per gallon (mpg): Average= 9.81, std = 0.53
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.48278344 3.48176411 3.48065888 3.47933108 3.47769854 3.4758352
#  3.47385926 3.47197297 3.47013828 3.4684953  3.46716278 3.4659885
#  3.46491897 3.46371928 3.46255012 3.46141068 3.46028768 3.45928801
#  3.45838294 3.45744724 3.45647138 3.45555322]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.66674728 1.64380106 1.60989841 1.57905236 1.53465692 1.50852715
#  1.46774716 1.44684086 1.42697119 1.39864483 1.36634202 1.33896805
#  1.31812832 1.29046624 1.27266028 1.25396999 1.22723995 1.20885659
#  1.15142022 1.11353506 1.08767294 1.08092962]
#
# Speed of all vehicles (m/s): Average= 3.47, std=1.36
#
# ####################
# Total number of vehicles that crossed the zero point: 529
#
# Flow (veh/hour): 1058.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [10.51155444 10.52284818 10.46721696 10.4328667  10.44570474 10.40718126
#  10.43117188 10.3633284  10.3234905  10.21123246 10.09274326  9.92807174
#   9.75230292  9.57061876  9.45181936  9.27078605  9.13330054  9.0106845
#   8.93214233  8.80238564  8.69499267  9.00611784]
#
# Miles per gallon (mpg): Average= 9.81, std = 0.64
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.42032535 3.42037063 3.42099635 3.42190224 3.4228942  3.42346917
#  3.42362104 3.4233205  3.42295983 3.422607   3.42226453 3.42200692
#  3.42150491 3.42172334 3.42148212 3.42140621 3.42124969 3.42109733
#  3.42093107 3.42075266 3.42050175 3.42027875]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.71696872 1.71205181 1.69100282 1.65850533 1.63801093 1.59251508
#  1.56514922 1.52342487 1.46422763 1.42645847 1.38202743 1.34172277
#  1.30234896 1.24197785 1.20824747 1.13957492 1.11316617 1.07091463
#  1.06234601 1.01975083 1.00116136 0.98022901]
#
# Speed of all vehicles (m/s): Average= 3.42, std=1.36
#
# ####################
# Total number of vehicles that crossed the zero point: 521
#
# Flow (veh/hour): 1042.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [10.97054778 10.94676681 10.9484099  10.86277262 10.74661762 10.63208493
#  10.4418278  10.39959861 10.24193085 10.16052193  9.98929081  9.84929663
#   9.69944224  9.5738588   9.49156964  9.38383015  9.2947109   9.18690422
#   9.0746701   8.91090064  8.790099    9.11068218]
#
# Miles per gallon (mpg): Average= 9.94, std = 0.71
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.44173536 3.43947402 3.4373049  3.43526486 3.43364098 3.43253251
#  3.43210107 3.43265858 3.4342692  3.4367328  3.43910246 3.43993965
#  3.44139135 3.44124873 3.44092851 3.44061648 3.44034891 3.44007951
#  3.43976221 3.43948276 3.43915114 3.43876888]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.66020819 1.63518422 1.61017294 1.56845624 1.53698565 1.47865958
#  1.4375178  1.38114954 1.35238494 1.32589213 1.28154119 1.23088044
#  1.17234522 1.13957424 1.0999595  1.07956436 1.05855509 1.02991927
#  1.00971337 0.98421229 0.95679255 0.93382705]
#
# Speed of all vehicles (m/s): Average= 3.44, std=1.27
#
# ####################
# Total number of vehicles that crossed the zero point: 523
#
# Flow (veh/hour): 1046.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [9.4801375  9.42797156 9.41566446 9.35105734 9.27864372 9.22252546
#  9.17449563 9.09777497 9.00305103 8.84147559 8.70777494 8.61307444
#  8.51165481 8.412281   8.3104956  8.18629145 8.04631727 7.95182283
#  7.81966549 7.71617566 7.65202932 8.12049643]
#
# Miles per gallon (mpg): Average= 8.65, std = 0.6
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.02805021 3.02529241 3.02260022 3.02025526 3.01846375 3.01682028
#  3.01488766 3.01211132 3.00969394 3.00739204 3.00495603 3.00223349
#  2.99948385 2.99672664 2.99399058 2.99137074 2.98898023 2.98662709
#  2.98410941 2.98147307 2.97901885 2.97679791]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.85164547 1.82379538 1.79140166 1.76105151 1.71488031 1.66662664
#  1.62874859 1.59897679 1.56883513 1.50845975 1.47505319 1.43937423
#  1.40994707 1.38471457 1.34589432 1.30194458 1.26533963 1.24876228
#  1.20219781 1.18625764 1.1801077  1.17680674]
#
# Speed of all vehicles (m/s): Average= 3.0, std=1.48
#
# ####################
# Total number of vehicles that crossed the zero point: 459
#
# Flow (veh/hour): 918.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [10.38667792 10.34125037 10.29225288 10.27968637 10.25644985 10.1829053
#  10.13712647 10.08587679 10.0140767   9.91038601  9.78441713  9.76272448
#   9.68344218  9.60392288  9.50357458  9.34324704  9.26888011  9.18559747
#   9.1245374   8.98444529  8.89032136  9.11300065]
#
# Miles per gallon (mpg): Average= 9.73, std = 0.48
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.46875346 3.47049499 3.47126961 3.47139238 3.47116196 3.47088729
#  3.47063083 3.47035213 3.46994811 3.46939528 3.46857125 3.46750736
#  3.46618883 3.4647251  3.46318112 3.4616718  3.46022619 3.45897005
#  3.45782669 3.45675039 3.4558042  3.45481938]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.64797532 1.61214943 1.58414365 1.55936539 1.54424715 1.52261412
#  1.49342509 1.47092964 1.4499822  1.43076522 1.39037913 1.360622
#  1.33513414 1.31967551 1.28789115 1.25879631 1.24229892 1.2299989
#  1.21889431 1.19225906 1.17735478 1.15286938]
#
# Speed of all vehicles (m/s): Average= 3.47, std=1.39
#
# ####################
# Total number of vehicles that crossed the zero point: 527
#
# Flow (veh/hour): 1054.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [9.9462596  9.94089677 9.84957265 9.86610207 9.89588678 9.85507381
#  9.80217275 9.83514982 9.77210107 9.67966967 9.55746459 9.48138579
#  9.35918468 9.21241264 9.05487154 8.91990258 8.80310152 8.63230565
#  8.40425169 8.22898278 8.12546274 8.52018431]
#
# Miles per gallon (mpg): Average= 9.31, std = 0.6
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.17206792 3.17089882 3.17235732 3.1716167  3.17024187 3.16825164
#  3.16593566 3.16365221 3.16164362 3.16012032 3.1592377  3.1590947
#  3.15987151 3.16172156 3.16437312 3.16647966 3.16717207 3.16691678
#  3.166474   3.16597149 3.16545311 3.16500205]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.80222584 1.76907133 1.69830096 1.65645098 1.61963643 1.57674857
#  1.54455825 1.50798223 1.47826528 1.45231041 1.41448132 1.38671581
#  1.35447341 1.30469144 1.26643459 1.22192    1.18701389 1.16439442
#  1.10606435 1.06359437 1.04785874 1.01239634]
#
# Speed of all vehicles (m/s): Average= 3.17, std=1.39
#
# ####################
# Total number of vehicles that crossed the zero point: 480
#
# Flow (veh/hour): 960.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [9.99288571 9.96042475 9.96207118 9.91823137 9.85098671 9.8295634
#  9.77648768 9.69191244 9.6899615  9.55603273 9.53582157 9.43179169
#  9.38160491 9.23139694 9.07170226 8.91485097 8.84354838 8.70001974
#  8.5672368  8.46165465 8.34397349 8.76641902]
#
# Miles per gallon (mpg): Average= 9.34, std = 0.53
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.27470062 3.27757953 3.28188145 3.28354519 3.28334997 3.2830337
#  3.2826895  3.28231963 3.2820625  3.2818648  3.28164556 3.28134083
#  3.28089353 3.2801884  3.27906826 3.27754685 3.27566806 3.27360665
#  3.27156361 3.26968937 3.2679056  3.26624182]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.73319165 1.69824803 1.66153563 1.6000176  1.57032731 1.52624337
#  1.48329895 1.44135046 1.4193816  1.3827106  1.34767641 1.32717625
#  1.29138165 1.25409952 1.20295234 1.16073455 1.12385507 1.1028807
#  1.09483538 1.08016834 1.03385636 0.98205821]
#
# Speed of all vehicles (m/s): Average= 3.28, std=1.34
#
# ####################
# Total number of vehicles that crossed the zero point: 498
#
# Flow (veh/hour): 996.0
#
# ####################
# (22, 18000)
#
# Miles per gallon for each vehicle (mpg):
# [10.96494992 10.90881039 10.81695797 10.67946628 10.60396993 10.48419082
#  10.42663922 10.28731114 10.14091721 10.01672287  9.93421451  9.79647102
#   9.63943679  9.45209501  9.37774592  9.22641852  9.14562525  9.07471625
#   8.95871862  8.80850709  8.70959308  9.04056364]
#
# Miles per gallon (mpg): Average= 9.84, std = 0.72
#
# ####################
# (22, 18000)
#
# Average speed of each vehicle (m/s):
# [3.44013132 3.43950642 3.43785441 3.44068621 3.44148533 3.44288732
#  3.44465671 3.44589483 3.44634729 3.44618268 3.4457804  3.44530303
#  3.44477781 3.4443289  3.44386762 3.44336544 3.44285314 3.44231808
#  3.44177394 3.44129147 3.44075311 3.44019252]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.69172768 1.64200358 1.59727953 1.55640152 1.50851413 1.4632707
#  1.41428792 1.36498888 1.3138311  1.26957081 1.23403134 1.19928994
#  1.13915462 1.06862822 1.03087493 0.97659532 0.95811144 0.93378528
#  0.91054291 0.8927488  0.8775412  0.8738113 ]
#
# Speed of all vehicles (m/s): Average= 3.44, std=1.22
#
# ####################
# Total number of vehicles that crossed the zero point: 524
#
# Flow (veh/hour): 1048.0
#
# MPG: [ 8.87430552 10.24563009  9.80551539  9.80738914  9.94119701  8.65185802
#   9.73339996  9.30647252  9.33993536  9.84063825], [0.4213855  0.54107933 0.52598543 0.64113852 0.71321538 0.596666
#  0.47915295 0.60164553 0.52981929 0.71822549]
# ####################
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1055091716389709.884241-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.52739343]
#
#
# Average time headway of controller(s):
# [62.21096732]
#
# Standard deviation of time headway of controller(s):
# [545.32437708]
#
# Time headway (s): Worst = 1.53, Avg= 62.21, std= 545.32
#
# ####################
# ####################
# Acceleration variation (m/s^2): []
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1100251716390025.0237758-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.51872558]
#
#
# Average time headway of controller(s):
# [27.68762912]
#
# Standard deviation of time headway of controller(s):
# [376.42411645]
#
# Time headway (s): Worst = 1.52, Avg= 27.69, std= 376.42
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1105551716390355.5843444-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.51976012]
#
#
# Average time headway of controller(s):
# [32.65131402]
#
# Standard deviation of time headway of controller(s):
# [383.33161586]
#
# Time headway (s): Worst = 1.52, Avg= 32.65, std= 383.33
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1111221716390682.0654545-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.52150673]
#
#
# Average time headway of controller(s):
# [18.83927353]
#
# Standard deviation of time headway of controller(s):
# [68.16390354]
#
# Time headway (s): Worst = 1.52, Avg= 18.84, std= 68.16
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1116401716391000.9775944-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.53972655]
#
#
# Average time headway of controller(s):
# [13.32649267]
#
# Standard deviation of time headway of controller(s):
# [42.03902711]
#
# Time headway (s): Worst = 1.54, Avg= 13.33, std= 42.04
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1141361716392496.919521-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.51875639]
#
#
# Average time headway of controller(s):
# [81.17343877]
#
# Standard deviation of time headway of controller(s):
# [616.78800827]
#
# Time headway (s): Worst = 1.52, Avg= 81.17, std= 616.79
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1147341716392854.7747838-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.52908221]
#
#
# Average time headway of controller(s):
# [49.71846382]
#
# Standard deviation of time headway of controller(s):
# [498.41471391]
#
# Time headway (s): Worst = 1.53, Avg= 49.72, std= 498.41
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626, 0.387709690717317]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1153251716393205.9664829-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.52309034]
#
#
# Average time headway of controller(s):
# [68.12448939]
#
# Standard deviation of time headway of controller(s):
# [617.6176094]
#
# Time headway (s): Worst = 1.52, Avg= 68.12, std= 617.62
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626, 0.387709690717317, 0.3349545902330695]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1159351716393575.5796177-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.52074487]
#
#
# Average time headway of controller(s):
# [17.32999366]
#
# Standard deviation of time headway of controller(s):
# [57.31343819]
#
# Time headway (s): Worst = 1.52, Avg= 17.33, std= 57.31
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626, 0.387709690717317, 0.3349545902330695, 0.3187264643706414]
#
# File: ./test_time_rollout/wu/stabilizing_the_ring_20240522-1205441716393944.2697668-0_emission.csv
# (1, 18000)
# Worst case time headway of controller(s):
# [1.51707843]
#
#
# Average time headway of controller(s):
# [10.16553024]
#
# Standard deviation of time headway of controller(s):
# [9.00480734]
#
# Time headway (s): Worst = 1.52, Avg= 10.17, std= 9.0
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626, 0.387709690717317, 0.3349545902330695, 0.3187264643706414, 0.2963885087786266]
#
# ####################
# ####################
#
# Final Aggregated Safety Metrics (across all files):
#
# Time to Collision across rollouts (s):
# 	Worst= [-1.7555425633283723, -2.063565152640591, -1.8022288428947828, -1.7426005557802233, -2.045547029435078, -1.724337652106949, -1.735076145453539, -1.8878530869858616, -1.808683184027386, -1.901462581281628]
# 	Avg= -1.85, std= 0.12
#
# 	Best: Avg= -2.1921149709217744e+16,         std= 4.3846670572252e+16
# 	Average: Avg= -1976697015317.92, std= 3953433494374.69
# 	Std: Avg= 206048933014616.38, std= 412145461117898.4
#
# DRAC across rollouts (m/s^2):
# 	Worst= [1.9627333705902916, 1.5745200976587097, 1.887160368101665, 2.022170189952257, 1.48603768261793, 2.0490065295524067, 2.121893695573065, 1.778410223414693, 1.9113631983350878, 2.1970617858392205]
# 	Avg= 1.9, std= 0.22
#
# CAV across rollouts (veh/hr): [0.38440373364912767, 0.2399101526749924, 0.3026372328648883, 0.2675272741637733, 0.26243446958821626, 0.387709690717317, 0.3349545902330695, 0.3187264643706414, 0.2963885087786266, 0.25341127331452534]
# 	Avg= 0.3, std= 0.05
#
# ####################
#
# Final Aggregated Efficiency Metrics (across all files):
#
# MPG across rollouts (miles/gallon): [8.874305519396666, 10.245630091270856, 9.805515392580363, 9.80738914252782, 9.941197008211207, 8.651858023344102, 9.733399964719315, 9.306472521478533, 9.33993535902468, 9.840638247365487]
# 	Avg= 9.55, std= 0.58
#
# Speed across rollouts (m/s): [3.140727810829817, 3.716995481235384, 3.4679871762549324, 3.4217120721604117, 3.438024310962334, 3.0027879534485566, 3.4654785630026437, 3.1656615381971633, 3.278108427530696, 3.4428290003326256]
# 	Avg= 3.35, std= 1.35
#
# Throughput/ Flow across rollouts (veh/hr): [951.9999999999999, 1128.0, 1058.0, 1042.0, 1046.0, 918.0, 1054.0, 960.0, 996.0, 1048.0]
# 	Avg= 1020.2, std= 59.51
#
# ####################
#
# Final Aggregated Stability Metrics (across all files):
#
# Time to stabilize (s), (time elapsed after warmup ends): [80.7, 86.7, 61.5, 103.3, 63.7, 98.4, 93.5, 87.6, 93.5, 145.8]
# 	Avg= 91.47, std= 22.3
#
# $1.85\thinspace\pm\thinspace0.12$ & $1.9\thinspace\pm\thinspace0.22$ & $9.55\thinspace\pm\thinspace0.58$ & $1020\thinspace\pm\thinspace59.51$

# %% [markdown]
# ### Ours Safety

# %%
# This is 5%, no need to make sure of a lot of stuff? 
# For CAV (Safety + Stability)
# !python test_rllib.py ./Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_5dfded14_2024-02-07_09-58-351869u4p3 168\
--method ours --length $LENGTH --warmup $WARMUP --horizon $HORIZON --shock_start_time $SHOCK_START_TIME --shock_end_time $SHOCK_END_TIME\
--num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render --num_controlled 1

# %%
# Only look at safety and stability
# !python eval_metrics.py --method ours --save_plots --horizon $HORIZON --warmup $WARMUP \
--start_time $SHOCK_START_TIME --end_time $SHOCK_END_TIME --num_rollouts $NUM_ROLLOUTS

# %% [markdown]
# ### Ours Efficiency

# %%
# For CAV (Efficiency)

# !python test_rllib.py ./Ours/Trained_policies/5_percent/PPO_DensityAwareRLEnv-v0_6106dcf6_2024-02-08_12-42-07_7vnf1n4 200\
--method ours --length $LENGTH --warmup $WARMUP --horizon $HORIZON --shock_start_time $SHOCK_START_TIME --shock_end_time $SHOCK_END_TIME\
--num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render --num_controlled 1

# %%
# Only look at Efficiency (Wipe out the previous data)
# !python eval_metrics.py --method ours --save_plots --horizon $HORIZON --warmup $WARMUP \
--start_time $SHOCK_START_TIME --end_time $SHOCK_END_TIME --num_rollouts $NUM_ROLLOUTS
# Out:
# Calculating metrics for 1 rollouts on files:
# ['./test_time_rollout/ours/density_aware_rl_20240522-1447061716403626.5540063-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1447141716403634.7622619-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1454121716404052.3828516-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1454221716404062.262318-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1502191716404539.4444394-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1502311716404551.2735155-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1510161716405016.058132-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1510211716405021.590342-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1518211716405501.4052477-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1518261716405506.0462844-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1526191716405979.596784-0_emission.csv', './test_time_rollout/ours/density_aware_rl_20240522-1526251716405985.384691-0_emission.csv']
#
# Vehicle ids: ['human_0' 'human_1' 'human_2' 'human_3' 'human_4' 'human_5' 'human_6'
#  'human_7' 'human_8' 'human_9' 'human_10' 'human_11' 'human_12' 'human_13'
#  'human_14' 'human_15' 'human_16' 'human_17' 'human_18' 'human_19'
#  'human_20' 'rl_0']
#
# (1, 1838)
# Worst case time to collision for each vehicle (s):
# [-1.12135958]
#
# Best case time to collision for each vehicle (s):
# [-452587.37170465]
#
# Average time to collision for each vehicle (s):
# [-1489.80130211]
#
# Standard deviation of time to collision for each vehicle (s):
# [12846.67964561]
#
# Time to Collision (s):
# 	Worst= -1.12
# 	Best= -452587.37
# 	Average= -1489.8
# 	Std= 12846.68
#
# ####################
# (1, 1838)
# Worst case drac for each vehicle (m/s^2):
# [2.54925401]
#
# DRAC (m/s^2):
# 	Worst= 2.55
#
# (1, 1826)
# Worst case time to collision for each vehicle (s):
# [-1.03911839]
#
# Best case time to collision for each vehicle (s):
# [-724275.97314335]
#
# Average time to collision for each vehicle (s):
# [-3091.20476652]
#
# Standard deviation of time to collision for each vehicle (s):
# [30169.94300702]
#
# Time to Collision (s):
# 	Worst= -1.04
# 	Best= -724275.97
# 	Average= -3091.2
# 	Std= 30169.94
#
# ####################
# (1, 1826)
# Worst case drac for each vehicle (m/s^2):
# [3.17248699]
#
# DRAC (m/s^2):
# 	Worst= 3.17
#
# (1, 1742)
# Worst case time to collision for each vehicle (s):
# [-1.04217218]
#
# Best case time to collision for each vehicle (s):
# [-365205.62932749]
#
# Average time to collision for each vehicle (s):
# [-1664.55584037]
#
# Standard deviation of time to collision for each vehicle (s):
# [10846.38997346]
#
# Time to Collision (s):
# 	Worst= -1.04
# 	Best= -365205.63
# 	Average= -1664.56
# 	Std= 10846.39
#
# ####################
# (1, 1742)
# Worst case drac for each vehicle (m/s^2):
# [3.09821676]
#
# DRAC (m/s^2):
# 	Worst= 3.1
#
# (1, 1783)
# Worst case time to collision for each vehicle (s):
# [-1.34252728]
#
# Best case time to collision for each vehicle (s):
# [-189513.07598363]
#
# Average time to collision for each vehicle (s):
# [-1651.19541294]
#
# Standard deviation of time to collision for each vehicle (s):
# [8677.12298855]
#
# Time to Collision (s):
# 	Worst= -1.34
# 	Best= -189513.08
# 	Average= -1651.2
# 	Std= 8677.12
#
# ####################
# (1, 1783)
# Worst case drac for each vehicle (m/s^2):
# [2.18486844]
#
# DRAC (m/s^2):
# 	Worst= 2.18
#
# (1, 2026)
# Worst case time to collision for each vehicle (s):
# [-2.81638497]
#
# Best case time to collision for each vehicle (s):
# [-4690938.39781262]
#
# Average time to collision for each vehicle (s):
# [-3205.74832826]
#
# Standard deviation of time to collision for each vehicle (s):
# [104220.30832264]
#
# Time to Collision (s):
# 	Worst= -2.82
# 	Best= -4690938.4
# 	Average= -3205.75
# 	Std= 104220.31
#
# ####################
# (1, 2026)
# Worst case drac for each vehicle (m/s^2):
# [0.72203661]
#
# DRAC (m/s^2):
# 	Worst= 0.72
#
# (1, 1892)
# Worst case time to collision for each vehicle (s):
# [-1.63702621]
#
# Best case time to collision for each vehicle (s):
# [-151208.99964024]
#
# Average time to collision for each vehicle (s):
# [-1085.21304304]
#
# Standard deviation of time to collision for each vehicle (s):
# [5282.48693769]
#
# Time to Collision (s):
# 	Worst= -1.64
# 	Best= -151209.0
# 	Average= -1085.21
# 	Std= 5282.49
#
# ####################
# (1, 1892)
# Worst case drac for each vehicle (m/s^2):
# [1.74624575]
#
# DRAC (m/s^2):
# 	Worst= 1.75
#
# (1, 1867)
# Worst case time to collision for each vehicle (s):
# [-1.5305257]
#
# Best case time to collision for each vehicle (s):
# [-1415831.17248368]
#
# Average time to collision for each vehicle (s):
# [-2160.1726624]
#
# Standard deviation of time to collision for each vehicle (s):
# [34693.72440793]
#
# Time to Collision (s):
# 	Worst= -1.53
# 	Best= -1415831.17
# 	Average= -2160.17
# 	Std= 34693.72
#
# ####################
# (1, 1867)
# Worst case drac for each vehicle (m/s^2):
# [1.82717271]
#
# DRAC (m/s^2):
# 	Worst= 1.83
#
# (1, 1909)
# Worst case time to collision for each vehicle (s):
# [-9.28639077]
#
# Best case time to collision for each vehicle (s):
# [-736451.97320045]
#
# Average time to collision for each vehicle (s):
# [-2216.80371317]
#
# Standard deviation of time to collision for each vehicle (s):
# [18598.16330098]
#
# Time to Collision (s):
# 	Worst= -9.29
# 	Best= -736451.97
# 	Average= -2216.8
# 	Std= 18598.16
#
# ####################
# (1, 1909)
# Worst case drac for each vehicle (m/s^2):
# [0.12719573]
#
# DRAC (m/s^2):
# 	Worst= 0.13
#
# (1, 1756)
# Worst case time to collision for each vehicle (s):
# [-1.28182378]
#
# Best case time to collision for each vehicle (s):
# [-974391.56670424]
#
# Average time to collision for each vehicle (s):
# [-1507.7840846]
#
# Standard deviation of time to collision for each vehicle (s):
# [24289.17812052]
#
# Time to Collision (s):
# 	Worst= -1.28
# 	Best= -974391.57
# 	Average= -1507.78
# 	Std= 24289.18
#
# ####################
# (1, 1756)
# Worst case drac for each vehicle (m/s^2):
# [2.22868097]
#
# DRAC (m/s^2):
# 	Worst= 2.23
#
# (1, 1982)
# Worst case time to collision for each vehicle (s):
# [-2.27416554]
#
# Best case time to collision for each vehicle (s):
# [-220768.8537992]
#
# Average time to collision for each vehicle (s):
# [-1097.49102885]
#
# Standard deviation of time to collision for each vehicle (s):
# [7142.92289248]
#
# Time to Collision (s):
# 	Worst= -2.27
# 	Best= -220768.85
# 	Average= -1097.49
# 	Std= 7142.92
#
# ####################
# (1, 1982)
# Worst case drac for each vehicle (m/s^2):
# [1.01661143]
#
# DRAC (m/s^2):
# 	Worst= 1.02
#
# (1, 1886)
# Worst case time to collision for each vehicle (s):
# [-1.58780315]
#
# Best case time to collision for each vehicle (s):
# [-1109345.5604636]
#
# Average time to collision for each vehicle (s):
# [-1978.25372577]
#
# Standard deviation of time to collision for each vehicle (s):
# [28115.67969083]
#
# Time to Collision (s):
# 	Worst= -1.59
# 	Best= -1109345.56
# 	Average= -1978.25
# 	Std= 28115.68
#
# ####################
# (1, 1886)
# Worst case drac for each vehicle (m/s^2):
# [1.61549346]
#
# DRAC (m/s^2):
# 	Worst= 1.62
#
# (1, 1804)
# Worst case time to collision for each vehicle (s):
# [-1.00113844]
#
# Best case time to collision for each vehicle (s):
# [-87237.41074852]
#
# Average time to collision for each vehicle (s):
# [-1115.87280805]
#
# Standard deviation of time to collision for each vehicle (s):
# [4236.65409296]
#
# Time to Collision (s):
# 	Worst= -1.0
# 	Best= -87237.41
# 	Average= -1115.87
# 	Std= 4236.65
#
# ####################
# (1, 1804)
# Worst case drac for each vehicle (m/s^2):
# [2.01842009]
#
# DRAC (m/s^2):
# 	Worst= 2.02
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [10.96088891 10.93584854 10.97237581 10.93301842 10.86275434 10.77233359
#  10.84613289 10.90580672 10.93126175 10.90968559 10.93056586 10.9714431
#  11.09419065 11.15111994 11.20564633 11.07898543 10.93154013 10.92587584
#  10.73488572 10.57996798 10.25012826 10.09111835]
#
# Miles per gallon (mpg): Average= 10.86, std = 0.26
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.01725446 4.01231288 4.00854187 4.00551882 4.00449162 4.00487021
#  4.00609829 4.00746855 4.0089073  4.01018884 4.01212467 4.01528391
#  4.01838831 4.02047041 4.02110676 4.02106181 4.02081256 4.02099965
#  4.02108346 4.02106556 4.02100241 4.02117342]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.45856847 1.46066604 1.40742125 1.37578676 1.3438632  1.28417249
#  1.19799748 1.17236357 1.14515468 1.11848198 1.08983768 1.06173678
#  1.03630557 1.01183421 0.98356901 0.9468485  0.91593565 0.88549512
#  0.85612136 0.83122715 0.75351856 0.61487956]
#
# Speed of all vehicles (m/s): Average= 4.01, std=1.09
#
# ####################
# Total number of vehicles that crossed the zero point: 122
#
# Flow (veh/hour): 1220.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [10.98674174 11.10484226 11.156891   11.13409291 11.29543106 11.29391555
#  11.29770512 11.35831642 11.39173363 11.31224159 11.30443121 11.2720963
#  11.13768216 11.10432227 10.77382181 10.65605182 10.55108166 10.52580835
#  10.36739623 10.24376674 10.17666516 10.17880162]
#
# Miles per gallon (mpg): Average= 10.94, std = 0.41
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.03703845 4.02526053 4.01443035 4.00469438 3.99696759 3.9911798
#  3.98716895 3.98557704 3.98575482 3.98736818 3.99082433 3.99438564
#  3.99813122 4.00060753 4.00166052 4.0016409  4.00115666 4.00068265
#  4.00005878 3.99996269 4.00014165 4.00031951]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.47038129 1.36998416 1.35878941 1.34387188 1.32135976 1.29260463
#  1.26705723 1.22776261 1.18948323 1.15607765 1.12054831 1.04765105
#  1.01930527 0.98883362 0.91822373 0.83214419 0.80406186 0.77782375
#  0.64416733 0.63462773 0.62723252 0.62894805]
#
# Speed of all vehicles (m/s): Average= 4.0, std=1.05
#
# ####################
# Total number of vehicles that crossed the zero point: 121
#
# Flow (veh/hour): 1210.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.0723055  11.06072832 11.07533468 11.20279472 11.19555883 11.34827457
#  11.29774106 11.23733151 11.12531599 10.84886457 10.73040164 10.56848021
#  10.55128238 10.55424814 10.56223356 10.55011979 10.55696765 10.56907295
#  10.46896512 10.40159174 10.18019417 10.20949174]
#
# Miles per gallon (mpg): Average= 10.79, std = 0.36
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.0481141  4.05843243 4.06128797 4.05926011 4.05516875 4.05007743
#  4.04487403 4.03941411 4.03427176 4.02919141 4.02537153 4.02237968
#  4.020738   4.01921041 4.01810886 4.01663336 4.01440919 4.01130863
#  4.00843828 4.00849897 4.02060505 4.02064206]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.34843516 1.34617032 1.33811828 1.30237428 1.26998205 1.15925221
#  1.12391007 1.08849514 1.05255116 0.96761532 0.9396087  0.85208539
#  0.83522399 0.82263469 0.8165337  0.81504368 0.81568863 0.81621325
#  0.81319427 0.75576572 0.60948493 0.61071874]
#
# Speed of all vehicles (m/s): Average= 4.03, std=0.98
#
# ####################
# Total number of vehicles that crossed the zero point: 122
#
# Flow (veh/hour): 1220.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.06978571 11.09575669 11.07409211 11.1547853  11.25601816 11.24531925
#  11.31139671 11.33938409 11.2773769  11.30114394 11.14286305 10.96675481
#  11.01856418 11.03748093 10.95294278 10.90896972 10.80860081 10.68260802
#  10.51044009 10.42595759 10.28892169 10.22265502]
#
# Miles per gallon (mpg): Average= 10.96, std = 0.33
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.00627924 4.01519215 4.03124058 4.05794183 4.05779728 4.05763768
#  4.05800206 4.05833429 4.05850095 4.05874538 4.05865151 4.05822302
#  4.0577773  4.05733401 4.05739499 4.05746128 4.05745603 4.05721172
#  4.05630746 4.05441482 4.05171328 4.04810407]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.52696966 1.502049   1.48534443 1.41008193 1.3785268  1.34458965
#  1.30924865 1.26212704 1.22638763 1.18817644 1.15883933 1.11051633
#  1.07929993 1.04324602 1.00965669 0.97711965 0.94192287 0.90686402
#  0.78481254 0.76181254 0.63769112 0.64063112]
#
# Speed of all vehicles (m/s): Average= 4.05, std=1.12
#
# ####################
# Total number of vehicles that crossed the zero point: 123
#
# Flow (veh/hour): 1230.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.61485997 11.55734752 11.43196465 11.34873853 11.14787906 10.98413005
#  10.91959991 10.83972527 10.8801733  10.80236144 10.91170604 10.86047608
#  10.86954666 10.85233377 10.83366371 10.81443371 10.81214337 10.81556551
#  10.79686914 10.75050234 10.68815811 10.52788302]
#
# Miles per gallon (mpg): Average= 10.96, std = 0.28
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.26070141 4.2561575  4.2496095  4.24150604 4.23253241 4.22380869
#  4.21765241 4.21605031 4.22125927 4.23675658 4.26622053 4.26881321
#  4.26990338 4.26987026 4.26927672 4.26863023 4.26799706 4.26772223
#  4.26749305 4.26767288 4.26801021 4.26800301]
#
# Standard deviation of speed of each vehicle (m/s):
# [0.61369809 0.59957633 0.59436336 0.53408011 0.43787636 0.46249101
#  0.38678596 0.38391902 0.37615551 0.39220627 0.23286534 0.20947603
#  0.20071886 0.20613303 0.17225176 0.17182676 0.17007388 0.16813533
#  0.17079621 0.16663732 0.18034802 0.06204499]
#
# Speed of all vehicles (m/s): Average= 4.25, std=0.31
#
# ####################
# Total number of vehicles that crossed the zero point: 128
#
# Flow (veh/hour): 1280.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.71338856 11.56770122 11.60261503 11.60861199 11.61952477 11.66933037
#  11.66642939 11.77899913 11.69340962 11.68389739 11.51732165 11.21601127
#  11.15277524 11.06579308 10.88439631 10.77991251 10.73396753 10.65868752
#  10.60058571 10.52641953 10.52624742 10.47458222]
#
# Miles per gallon (mpg): Average= 11.22, std = 0.47
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.2497881  4.25123324 4.25049349 4.24813409 4.24496062 4.24109226
#  4.23624587 4.23011752 4.22300326 4.21545462 4.20806002 4.20155273
#  4.19635657 4.19289291 4.19133834 4.19082119 4.19163993 4.19223397
#  4.19244049 4.19285991 4.19359523 4.19411292]
#
# Standard deviation of speed of each vehicle (m/s):
# [0.98903672 0.91170793 0.8826356  0.76111247 0.74527899 0.73154858
#  0.71374216 0.70215743 0.69077866 0.68370024 0.68103362 0.63237985
#  0.61642438 0.59998528 0.58158187 0.42325487 0.41399846 0.40552551
#  0.31484317 0.30975024 0.30909339 0.31111949]
#
# Speed of all vehicles (m/s): Average= 4.21, std=0.61
#
# ####################
# Total number of vehicles that crossed the zero point: 127
#
# Flow (veh/hour): 1270.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.60823811 11.53461244 11.46869024 11.54088861 11.48976764 11.59305427
#  11.54952503 11.38192853 11.42186563 11.28708256 11.07941291 11.03706703
#  11.00201354 10.96281998 10.88932615 10.92553104 10.85049013 10.81769433
#  10.81917447 10.76961067 10.70559523 10.64970834]
#
# Miles per gallon (mpg): Average= 11.15, std = 0.33
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.15897991 4.15930148 4.16601304 4.17754527 4.19623662 4.21665919
#  4.22835607 4.23415023 4.2339851  4.234575   4.23495248 4.23538516
#  4.23559049 4.23494676 4.23535058 4.2345662  4.23276311 4.22889061
#  4.22268655 4.21473024 4.20592259 4.19823113]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.0629934  1.05208758 1.042143   1.03305237 0.94792306 0.9081743
#  0.89413974 0.74435745 0.72537134 0.69837498 0.60782851 0.59954625
#  0.52512395 0.51653096 0.50956142 0.50178242 0.48514416 0.48355481
#  0.4919349  0.51068169 0.5336581  0.5544145 ]
#
# Speed of all vehicles (m/s): Average= 4.21, std=0.7
#
# ####################
# Total number of vehicles that crossed the zero point: 129
#
# Flow (veh/hour): 1290.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.36516207 11.38912585 11.38357024 11.3174951  11.27342522 11.25485657
#  11.23474129 11.23196409 11.20779625 11.15006785 11.11277359 11.04539863
#  11.0149276  10.9893268  10.99616033 10.98956795 10.92041383 10.8886794
#  10.80850818 10.8054587  10.81219498 10.75345978]
#
# Miles per gallon (mpg): Average= 11.09, std = 0.2
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.37151723 4.37136577 4.37018477 4.36862187 4.36746673 4.36657649
#  4.3664931  4.36682025 4.36716073 4.36754851 4.36789083 4.36813454
#  4.36844567 4.3682555  4.36809509 4.36819625 4.36842568 4.36848504
#  4.36833695 4.36810272 4.36812137 4.36831446]
#
# Standard deviation of speed of each vehicle (m/s):
# [3.51355482e-01 3.45711300e-01 3.39741619e-01 3.38149949e-01
#  2.82333067e-01 2.76054035e-01 2.69575691e-01 2.64313784e-01
#  2.61128116e-01 2.55809014e-01 2.57940705e-01 1.97012852e-01
#  1.93228359e-01 1.87686051e-01 1.84898862e-01 1.81056202e-01
#  1.80817317e-01 1.87064724e-01 2.07441856e-02 1.91023516e-02
#  1.56683218e-02 2.96651592e-13]
#
# Speed of all vehicles (m/s): Average= 4.37, std=0.21
#
# ####################
# Total number of vehicles that crossed the zero point: 132
#
# Flow (veh/hour): 1320.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.11940342 11.20789759 11.31136193 11.47348523 11.49053428 11.59160045
#  11.65422765 11.81141398 11.80374081 11.86149193 11.85121802 11.74486785
#  11.60984686 11.51457341 11.3987706  11.27258476 11.12713938 10.98888096
#  10.83397573 10.66986028 10.59442699 10.60840696]
#
# Miles per gallon (mpg): Average= 11.34, std = 0.4
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.16732526 4.17970351 4.18543092 4.18477713 4.18064018 4.17373875
#  4.16524325 4.1561424  4.14706697 4.138632   4.13083772 4.12399608
#  4.11765133 4.11136785 4.10553168 4.1000298  4.0954201  4.09180747
#  4.09079383 4.09649675 4.09485205 4.09304787]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.63460368 1.62308715 1.60281471 1.57712591 1.55167083 1.52865377
#  1.50688021 1.45955238 1.42876565 1.39658974 1.36397475 1.32891434
#  1.29200425 1.18000782 1.11697014 1.09314058 1.07037563 1.04066567
#  1.01863161 0.94227315 0.93934948 0.85646912]
#
# Speed of all vehicles (m/s): Average= 4.13, std=1.3
#
# ####################
# Total number of vehicles that crossed the zero point: 125
#
# Flow (veh/hour): 1250.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [12.23949032 12.18560808 12.18048931 12.08031048 12.00415625 12.05447947
#  12.04843103 12.07765129 12.09272563 12.02861909 11.99165303 11.82550286
#  11.78855492 11.49949103 11.51501924 11.49935599 11.42180316 11.37400816
#  11.30820577 11.19819744 11.10842884 11.00026533]
#
# Miles per gallon (mpg): Average= 11.75, std = 0.38
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.45893612 4.45645313 4.45419878 4.45185866 4.44951695 4.44654288
#  4.44228408 4.43739345 4.43184793 4.42671752 4.42268981 4.41948921
#  4.41780194 4.41740736 4.41786807 4.41922321 4.42061268 4.42166155
#  4.42227909 4.42245278 4.42273043 4.42282059]
#
# Standard deviation of speed of each vehicle (m/s):
# [0.63946514 0.62707072 0.6140505  0.60173915 0.55181211 0.53885424
#  0.5309378  0.52530935 0.5206514  0.51448019 0.50768525 0.49873979
#  0.48964279 0.34150194 0.33594136 0.32868239 0.32013641 0.31645751
#  0.31694563 0.27464596 0.27625897 0.20499622]
#
# Speed of all vehicles (m/s): Average= 4.43, std=0.45
#
# ####################
# Total number of vehicles that crossed the zero point: 135
#
# Flow (veh/hour): 1350.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [11.31433383 11.24022852 11.06111963 11.18274455 11.19501897 11.26477269
#  11.24969641 11.21368448 11.20443873 11.14986083 11.13230079 11.15317356
#  10.96887235 10.93017709 10.97132521 10.79402661 10.73198786 10.73363426
#  10.72935548 10.62964708 10.4357887  10.47031708]
#
# Miles per gallon (mpg): Average= 10.99, std = 0.26
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.15067471 4.14925086 4.14669466 4.14297292 4.13705601 4.12951189
#  4.12019192 4.11088137 4.10279298 4.09761915 4.0973682  4.10325345
#  4.11640479 4.13506108 4.15357859 4.15318384 4.15293325 4.15281047
#  4.15279366 4.15307071 4.15286325 4.15272185]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.09978056 1.08500325 1.04907745 1.03898828 1.02601377 1.01287624
#  1.00100119 0.99215945 0.98220997 0.96587085 0.94874656 0.92589568
#  0.91278288 0.9011712  0.78636739 0.73970099 0.71624442 0.69148747
#  0.66770069 0.64286928 0.48575099 0.48577981]
#
# Speed of all vehicles (m/s): Average= 4.13, std=0.87
#
# ####################
# Total number of vehicles that crossed the zero point: 125
#
# Flow (veh/hour): 1250.0
#
# ####################
# (22, 3600)
#
# Miles per gallon for each vehicle (mpg):
# [10.97710258 11.12567054 11.10380448 11.10494248 11.14873655 11.23671736
#  11.20137498 11.25487337 11.26812773 11.11513487 11.13977281 11.09397882
#  11.10432572 11.02721004 10.86843359 10.73996494 10.56810236 10.35913654
#  10.28417431 10.23548398 10.0804354  10.10799303]
#
# Miles per gallon (mpg): Average= 10.87, std = 0.39
#
# ####################
# (22, 3600)
#
# Average speed of each vehicle (m/s):
# [4.00822597 4.0017056  3.99686171 3.99431165 3.99351765 3.99309266
#  3.9915777  3.98779162 3.98181938 3.97465916 3.96681199 3.95881642
#  3.95176013 3.94584038 3.94113404 3.93724111 3.93317412 3.92782158
#  3.92160604 3.91467547 3.90866079 3.90384838]
#
# Standard deviation of speed of each vehicle (m/s):
# [1.50298063 1.39506303 1.38034133 1.29828393 1.27215044 1.243673
#  1.21363991 1.18405043 1.1576852  1.12864051 1.01581664 1.00791645
#  0.99684944 0.98426842 0.96988224 0.95547057 0.89696131 0.85203216
#  0.83164427 0.83529324 0.83925511 0.84391592]
#
# Speed of all vehicles (m/s): Average= 3.96, std=1.08
#
# ####################
# Total number of vehicles that crossed the zero point: 119
#
# Flow (veh/hour): 1190.0
#
# MPG: [10.8625261  10.93744712 10.78942268 10.95871898 10.95727551 11.21548216
#  11.15382259 11.08841247 11.34271405 11.75102031 10.98893203 10.87024984], [0.25604993 0.41154008 0.35645051 0.32764495 0.27679828 0.46952088
#  0.32507829 0.19995228 0.39771715 0.38384483 0.26228869 0.39294232]
# ####################
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1447061716403626.5540063-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.03393796]
#
#
# Average time headway of controller(s):
# [4.54246345]
#
# Standard deviation of time headway of controller(s):
# [1.70210668]
#
# Time headway (s): Worst = 1.03, Avg= 4.54, std= 1.7
#
# ####################
# ####################
# Acceleration variation (m/s^2): []
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1447141716403634.7622619-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02784821]
#
#
# Average time headway of controller(s):
# [4.87234636]
#
# Standard deviation of time headway of controller(s):
# [2.2970545]
#
# Time headway (s): Worst = 1.03, Avg= 4.87, std= 2.3
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1454121716404052.3828516-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02704635]
#
#
# Average time headway of controller(s):
# [4.38933853]
#
# Standard deviation of time headway of controller(s):
# [1.50875642]
#
# Time headway (s): Worst = 1.03, Avg= 4.39, std= 1.51
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1454221716404062.262318-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02901764]
#
#
# Average time headway of controller(s):
# [4.52997239]
#
# Standard deviation of time headway of controller(s):
# [2.19543791]
#
# Time headway (s): Worst = 1.03, Avg= 4.53, std= 2.2
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1502191716404539.4444394-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.03658509]
#
#
# Average time headway of controller(s):
# [4.13355043]
#
# Standard deviation of time headway of controller(s):
# [0.67694718]
#
# Time headway (s): Worst = 1.04, Avg= 4.13, std= 0.68
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1502311716404551.2735155-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02875705]
#
#
# Average time headway of controller(s):
# [4.07161545]
#
# Standard deviation of time headway of controller(s):
# [1.10701172]
#
# Time headway (s): Worst = 1.03, Avg= 4.07, std= 1.11
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1510161716405016.058132-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02044472]
#
#
# Average time headway of controller(s):
# [3.86731293]
#
# Standard deviation of time headway of controller(s):
# [1.47460786]
#
# Time headway (s): Worst = 1.02, Avg= 3.87, std= 1.47
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1510211716405021.590342-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.72393139]
#
#
# Average time headway of controller(s):
# [3.70256679]
#
# Standard deviation of time headway of controller(s):
# [0.37918679]
#
# Time headway (s): Worst = 1.72, Avg= 3.7, std= 0.38
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1518211716405501.4052477-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02171147]
#
#
# Average time headway of controller(s):
# [3.96446284]
#
# Standard deviation of time headway of controller(s):
# [3.08097529]
#
# Time headway (s): Worst = 1.02, Avg= 3.96, std= 3.08
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985, 0.0]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1518261716405506.0462844-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02452427]
#
#
# Average time headway of controller(s):
# [3.16828401]
#
# Standard deviation of time headway of controller(s):
# [0.72492973]
#
# Time headway (s): Worst = 1.02, Avg= 3.17, std= 0.72
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985, 0.0, 0.2855898896508566]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1526191716405979.596784-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [1.02407216]
#
#
# Average time headway of controller(s):
# [4.50888711]
#
# Standard deviation of time headway of controller(s):
# [1.90401278]
#
# Time headway (s): Worst = 1.02, Avg= 4.51, std= 1.9
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985, 0.0, 0.2855898896508566, 0.08699484455904573]
#
# File: ./test_time_rollout/ours/density_aware_rl_20240522-1526251716405985.384691-0_emission.csv
# (1, 3600)
# Worst case time headway of controller(s):
# [0.99005167]
#
#
# Average time headway of controller(s):
# [6.14791472]
#
# Standard deviation of time headway of controller(s):
# [7.15989556]
#
# Time headway (s): Worst = 0.99, Avg= 6.15, std= 7.16
#
# ####################
# ####################
# Acceleration variation (m/s^2): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985, 0.0, 0.2855898896508566, 0.08699484455904573, 0.17589799470910966]
#
# ####################
# ####################
#
# Final Aggregated Safety Metrics (across all files):
#
# Time to Collision across rollouts (s):
# 	Worst= [-1.1213595786130923, -1.0391183912584712, -1.0421721842019755, -1.342527283926597, -2.816384968978259, -1.637026208607129, -1.53052569862198, -9.286390767337837, -1.2818237779806807, -2.2741655383415473, -1.5878031509333448, -1.001138440473852]
# 	Avg= -2.16, std= 2.21
#
# 	Best: Avg= -926479.67,         std= 1204487.06
# 	Average: Avg= -1855.34, std= 685.35
# 	Std: Avg= 24093.27, std= 26126.49
#
# DRAC across rollouts (m/s^2):
# 	Worst= [2.5492540090357516, 3.172486990081429, 3.0982167622654306, 2.1848684441231265, 0.7220366082760716, 1.7462457497091861, 1.827172707785366, 0.1271957273378867, 2.228680971678914, 1.0166114282350838, 1.6154934633916158, 2.018420094992589]
# 	Avg= 1.86, std= 0.87
#
# CAV across rollouts (veh/hr): [0.20652166233687808, 0.2385259986933162, 0.2009275165943029, 0.20455682790852284, 0.04464738046825066, 0.12748686344349042, 0.18178274018554985, 0.0, 0.2855898896508566, 0.08699484455904573, 0.17589799470910966, 0.2954445315858277]
# 	Avg= 0.17, std= 0.09
#
# ####################
#
# Final Aggregated Efficiency Metrics (across all files):
#
# MPG across rollouts (miles/gallon): [10.862526096938295, 10.937447118992075, 10.789422675071812, 10.958718979270289, 10.957275507100336, 11.215482157469102, 11.153822585140146, 11.088412468415546, 11.342714048943058, 11.75102030552683, 10.98893203166736, 10.870249838747222]
# 	Avg= 11.08, std= 0.34
#
# Speed across rollouts (m/s): [4.014555716844216, 4.000227825665437, 4.031201641293462, 4.051441859700289, 4.2534384958400135, 4.214928511910447, 4.2145371727565, 4.368298160911766, 4.133206040665684, 4.431944828271006, 4.134713164403755, 3.9606797075977296]
# 	Avg= 4.15, std= 0.81
#
# Throughput/ Flow across rollouts (veh/hr): [1220.0, 1210.0, 1220.0, 1230.0, 1280.0, 1270.0, 1290.0, 1320.0, 1250.0, 1350.0, 1250.0, 1190.0]
# 	Avg= 1256.67, std= 45.34
#
# ####################
#
# Final Aggregated Stability Metrics (across all files):
#
# Time to stabilize (s), (time elapsed after warmup ends): [251.7, 223.6, 253.4, 235.7, 219.3, 253.8, 239.3, 233.0, 228.7, 231.3, 229.8, 253.1]
# 	Avg= 237.73, std= 11.86
#
# $2.16\thinspace\pm\thinspace2.21$ & $1.86\thinspace\pm\thinspace0.87$ & $11.08\thinspace\pm\thinspace0.34$ & $1256\thinspace\pm\thinspace45.34$
